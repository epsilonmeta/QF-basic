# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = [9,8,7,7,6,9,7,6,8,8,8,7,9,7,7,8]

# %%
hist = np.histogram(df, bins=10, range=None, density=None, weights=None)

# %%
plt.hist(df, bins='auto')
# Out:
# (array([2., 6., 8.]),
#  array([6., 7., 8., 9.]),
#  <BarContainer object of 3 artists>)
