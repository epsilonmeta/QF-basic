# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

from pypfopt.expected_returns import mean_historical_return,ema_historical_return,capm_return
from pypfopt.risk_models import CovarianceShrinkage ,risk_matrix
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.black_litterman import BlackLittermanModel ,market_implied_prior_returns,market_implied_risk_aversion

# %%
symbols= ['RELIANCE.NS','HDFCBANK.NS','ICICIBANK.NS','HDFCBANK.NS','INFY.NS','ITC.NS','TCS.NS','HINDUNILVR.NS','SBIN.NS','BHARTIARTL.NS']
sd = yf.download(symbols, interval='1d')['Close']
sd.reset_index(inplace=True)
# rename column ['Date'] to ['date']
sd.rename(columns={'^NSEI':'Nifty50'}, inplace=True)
# reaarange columns
sd = sd[['Date','RELIANCE.NS','HDFCBANK.NS','ICICIBANK.NS','HDFCBANK.NS','INFY.NS','ITC.NS','TCS.NS','HINDUNILVR.NS','SBIN.NS','BHARTIARTL.NS','Nifty50']]
symbols.remove('^NSEI')
symbols.append('Nifty50')
sd
# Out:
# [*********************100%***********************]  9 of 9 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14900\2387055268.py in <module>
#       5 sd.rename(columns={'^NSEI':'Nifty50'}, inplace=True)
#       6 # reaarange columns
# ----> 7 sd = sd[['Date','RELIANCE.NS','HDFCBANK.NS','ICICIBANK.NS','HDFCBANK.NS','INFY.NS','ITC.NS','TCS.NS','HINDUNILVR.NS','SBIN.NS','BHARTIARTL.NS','Nifty50']]
#       8 symbols.remove('^NSEI')
#       9 symbols.append('Nifty50')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941             raise KeyError(f"{not_found} not in index")
#    5942
#    5943     @overload
#
# KeyError: "['Nifty50'] not in index"

# %%
sd['Date'] = pd.to_datetime(sd['Date'])
sd['Date'] = sd['Date'].dt.strftime('%Y-%m-%d')
# get month and year from8 date
Month = pd.DatetimeIndex(sd['Date']).month
Year = pd.DatetimeIndex(sd['Date']).year
sd['month_year'] = Year.astype(str) + '-' + Month.astype(str)
sd.reset_index(inplace=True, drop=True)
sd
# Out:
#             Date  BHARTIARTL.NS  HDFCBANK.NS  HINDUNILVR.NS  ICICIBANK.NS  \
# 0     1996-01-01            NaN     2.980000      61.805000           NaN
# 1     1996-01-02            NaN     2.975000      62.465000           NaN
# 2     1996-01-03            NaN     2.985000      62.095001           NaN
# 3     1996-01-04            NaN     2.965000      62.099998           NaN
# 4     1996-01-05            NaN     2.960000      62.000000           NaN
# ...          ...            ...          ...            ...           ...
# 7182  2024-08-05    1465.699951  1615.750000    2715.899902   1172.599976
# 7183  2024-08-06    1443.550049  1601.199951    2750.050049   1166.849976
# 7184  2024-08-07    1441.750000  1623.500000    2744.050049   1172.449951
# 7185  2024-08-08    1451.800049  1642.699951    2733.199951   1164.599976
# 7186  2024-08-09    1464.099976  1650.199951    2747.199951   1171.599976
#
#           INFY.NS      ITC.NS  RELIANCE.NS     SBIN.NS       TCS.NS month_year
# 0        0.796679    5.583333    14.691803   18.823240          NaN     1996-1
# 1        0.793457    5.372222    14.577553   18.224106          NaN     1996-1
# 2        0.798828    5.200000    14.688232   17.738192          NaN     1996-1
# 3        0.793554    5.297777    14.552561   17.676863          NaN     1996-1
# 4        0.784179    5.202222    14.452592   17.577793          NaN     1996-1
# ...           ...         ...          ...         ...          ...        ...
# 7182  1751.900024  486.000000  2894.649902  811.650024  4155.049805     2024-8
# 7183  1751.099976  486.299988  2912.100098  797.700012  4171.200195     2024-8
# 7184  1791.650024  492.649994  2929.649902  808.650024  4200.450195     2024-8
# 7185  1743.150024  494.750000  2898.250000  808.049988  4172.549805     2024-8
# 7186  1770.750000  495.899994  2948.600098  824.299988  4228.750000     2024-8
#
# [7187 rows x 11 columns]

# %%
# get first and last day of month for each month in the data
months = sd.groupby('month_year')['Date'].agg([ 'last'])
months.sort_values(by='last', inplace=True)
months
# Out:
#                   last
# month_year
# 1996-1      1996-01-31
# 1996-2      1996-02-29
# 1996-3      1996-03-29
# 1996-4      1996-04-30
# 1996-5      1996-05-31
# ...                ...
# 2024-4      2024-04-30
# 2024-5      2024-05-31
# 2024-6      2024-06-28
# 2024-7      2024-07-31
# 2024-8      2024-08-09
#
# [344 rows x 1 columns]

# %%
sd1 = sd.copy()
sd = sd[sd['Date'].isin(months['last'])]
inde= sd[sd['month_year'] == '2009-1'].index[0]
sd = sd[sd['Date'] >= sd['Date'][inde]]
sd1 = sd1[sd1['Date'] >= sd['Date'][inde]]
sd1.reset_index(inplace=True, drop=True)
# sd1 = sd

sd.reset_index(inplace=True, drop=True)
# returns = sd[symbols].pct_change()
sd1
# Out:
#             Date  BHARTIARTL.NS  HDFCBANK.NS  HINDUNILVR.NS  ICICIBANK.NS  \
# 0     2009-01-30     285.676025    92.559998     261.649994     75.681816
# 1     2009-02-02     277.497101    88.870003     261.899994     70.018181
# 2     2009-02-03     281.642883    89.820000     266.100006     71.272728
# 3     2009-02-04     285.833740    88.584999     267.899994     70.854546
# 4     2009-02-05     283.287689    88.425003     263.399994     71.009087
# ...          ...            ...          ...            ...           ...
# 3823  2024-08-05    1465.699951  1615.750000    2715.899902   1172.599976
# 3824  2024-08-06    1443.550049  1601.199951    2750.050049   1166.849976
# 3825  2024-08-07    1441.750000  1623.500000    2744.050049   1172.449951
# 3826  2024-08-08    1451.800049  1642.699951    2733.199951   1164.599976
# 3827  2024-08-09    1464.099976  1650.199951    2747.199951   1171.599976
#
#           INFY.NS      ITC.NS  RELIANCE.NS     SBIN.NS       TCS.NS month_year
# 0      163.331253   60.033333   302.552704  115.099998   127.900002     2009-1
# 1      159.956253   59.400002   292.586456  109.580002   122.824997     2009-2
# 2      160.312500   60.299999   298.575348  109.230003   124.962502     2009-2
# 3      160.206253   60.299999   298.872498  109.680000   124.662498     2009-2
# 4      156.981247   60.433334   294.597992  109.474998   120.724998     2009-2
# ...           ...         ...          ...         ...          ...        ...
# 3823  1751.900024  486.000000  2894.649902  811.650024  4155.049805     2024-8
# 3824  1751.099976  486.299988  2912.100098  797.700012  4171.200195     2024-8
# 3825  1791.650024  492.649994  2929.649902  808.650024  4200.450195     2024-8
# 3826  1743.150024  494.750000  2898.250000  808.049988  4172.549805     2024-8
# 3827  1770.750000  495.899994  2948.600098  824.299988  4228.750000     2024-8
#
# [3828 rows x 11 columns]

# %%
sd
# Out:
#            Date  BHARTIARTL.NS  HDFCBANK.NS  HINDUNILVR.NS  ICICIBANK.NS  \
# 0    2009-01-30     285.676025    92.559998     261.649994     75.681816
# 1    2009-02-27     287.726379    88.949997     253.500000     59.554546
# 2    2009-03-31     281.980865    97.339996     237.500000     60.509090
# 3    2009-04-30     339.773987   110.035004     234.750000     87.454544
# 4    2009-05-29     369.921051   144.449997     230.800003    134.572723
# ..          ...            ...          ...            ...           ...
# 183  2024-04-30    1322.300049  1520.099976    2230.449951   1150.400024
# 184  2024-05-31    1372.750000  1531.550049    2329.050049   1121.050049
# 185  2024-06-28    1444.050049  1683.800049    2473.050049   1199.599976
# 186  2024-07-31    1491.550049  1615.750000    2705.649902   1214.900024
# 187  2024-08-09    1464.099976  1650.199951    2747.199951   1171.599976
#
#          INFY.NS      ITC.NS  RELIANCE.NS     SBIN.NS       TCS.NS month_year
# 0     163.331253   60.033333   302.552704  115.099998   127.900002     2009-1
# 1     153.906250   61.016666   289.397736  102.529999   120.775002     2009-2
# 2     165.487503   61.616665   348.532196  106.709999   134.637497     2009-3
# 3     188.656250   62.900002   413.781281  127.860001   155.524994     2009-4
# 4     200.637497   61.216667   519.318115  186.884995   176.149994     2009-5
# ..           ...         ...          ...         ...          ...        ...
# 183  1420.550049  435.649994  2934.000000  826.250000  3820.649902     2024-4
# 184  1406.900024  426.450012  2860.800049  830.349976  3670.949951     2024-5
# 185  1566.750000  424.899994  3130.800049  848.950012  3904.149902     2024-6
# 186  1868.250000  495.350006  3010.850098  872.400024  4385.350098     2024-7
# 187  1770.750000  495.899994  2948.600098  824.299988  4228.750000     2024-8
#
# [188 rows x 11 columns]

# %%
model = linearregression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14900\2233867560.py in <module>
# ----> 1 model = linearregression()
#
# NameError: name 'linearregression' is not defined

# %%
# # black litterman model -- sample test
# from pypfopt import black_litterman, risk_models
# from pypfopt import BlackLittermanModel, plotting
# from pypfopt import expected_returns
#
# S = risk_models.CovarianceShrinkage(sd[symbols[:-1]]).ledoit_wolf()
# mu = expected_returns.mean_historical_return(sd[symbols[:-1]])
# delta = black_litterman.market_implied_risk_aversion(sd[symbols[:-1]])
# # prior = black_litterman.market_implied_prior_returns(mcaps, delta, cov_matrix)
# prior = black_litterman.market_implied_prior_returns(sd[symbols[:-1]].all(), delta, S, risk_free_rate=0.02)
# bl = BlackLittermanModel(S, mu, delta)
# bl.bl_weights()

# %%
# create folder if not exists
import os
if not os.path.exists('Results'):
    os.makedirs('Results')

# %% [markdown]
# ## Months where returns are negative (all returns are negative,so can't invest)
# - 2011-02-28
# - 2016-02-29
# - 2018-03-28

# %%
# create folder if not exists
if not os.path.exists('Results/BlackLittermanModel'):
    os.makedirs('Results/BlackLittermanModel')

# creating a dataframe to store all the results
BlackLittermanModel_results = pd.DataFrame(columns=['returns_method','risk_model','weight_method','portfolio_return','nifty_return','return_months','holding_month','error_dates','no_of_error_dates'])
# BlackLittermanModel_results = pd.read_csv('AllResults.csv')

# creating a list of column names
column = ['Date','month_year','holding_months','returns_months']
column = column + [i + '_weights' for i in symbols[:-1]] + [i + '_pct_change' for i in symbols]

list_of_dates = ['2011-02-28','2016-02-29','2018-03-28']

# parameters
returns_methods = [mean_historical_return,ema_historical_return,capm_return]
risk_models_methods = ['sample_cov','semicovariance','exp_cov','ledoit_wolf','ledoit_wolf_single_factor','ledoit_wolf_constant_correlation','oracle_approximating']
method =['bl_weights']

# get oputput for each method in method list and each risk model in risk_models_methods list and each return in returns list
for returns_method in returns_methods: # for each returns method
    for risk_model in risk_models_methods: # for each risk model
        for weight_mrthod in method: # for each weight method
            storing_weights = pd.DataFrame(columns=column) # create a dataframe to store weights
            for returns_months in range(6,0,-1): # for each return month
                for holding_months in range(6,0,-1):
                    main_df_weights = pd.DataFrame(columns=column) # create a dataframe to store weights
                    dates=[] # create a list to store error dates
                    print('start',returns_method.__name__,risk_model,weight_mrthod,returns_months,holding_months,len(sd)) # print the parameters
                    for ind in range(12,len(sd)-(holding_months)): # for each date in the data
                        if sd['Date'][ind] not in list_of_dates: # if date is not in list of dates
                            df = sd1[(sd1['Date'] <= sd['Date'][ind]) & (sd1['Date'] >= sd['Date'][ind-returns_months])][symbols[:-1]] # get data for returns months
                            try:
                                mu = returns_method(df) # get returns using returns method
                                S = risk_matrix(df, method=risk_model) # get risk matrix using risk model
                                delta = market_implied_risk_aversion(df) # get delta
                                bl = BlackLittermanModel(S, mu, delta) # create black litterman model
                                raw_weights = getattr(bl, weight_mrthod)() # get weights using weight method
                                cleaned_weights = bl.clean_weights() # clean weights
                            except Exception as e:
                                print(returns_method.__name__,risk_model,weight_mrthod,sd['Date'][ind],e) # print error
                                dates.append(sd['Date'][ind]) # append error date to list
                                continue
                            cleaned_weights = pd.DataFrame.from_dict(cleaned_weights, orient='index', columns=['weights']) # convert weights to dataframe
                            cleaned_weights[cleaned_weights['weights'] < 0] = 0 # set negative weights to 0
                            cleaned_weights[cleaned_weights['weights'] > 0] = cleaned_weights[cleaned_weights['weights'] > 0] / cleaned_weights[cleaned_weights['weights'] > 0].sum() # normalize weights
                            returns_df = pd.DataFrame(columns=symbols) # create a dataframe to store returns
                            returns_df.loc[0] = sd[sd['Date'] == sd['Date'][ind]][symbols].iloc[0] # insert startrting prices
                            returns_df.loc[1] = sd[sd['Date'] == sd['Date'][ind+holding_months]][symbols].iloc[0] # insert ending prices
                            main_df_weights.loc[len(main_df_weights)] = [sd['Date'][ind],sd['month_year'][ind],str(returns_months),str(holding_months),] + cleaned_weights['weights'].tolist() + returns_df.pct_change().iloc[1].tolist() # insert data into main dataframe

                    for symbol in symbols[:-1]:
                        main_df_weights[symbol + '_multiply'] = main_df_weights[symbol + '_weights'] * main_df_weights[symbol + '_pct_change'] # multiply weights with returns
                    main_df_weights['portfolio_return'] = main_df_weights[[i + '_multiply' for i in symbols[:-1]]].mean(axis=1) # get portfolio returns


                    main_df_weights['nifty_cummulative_return'] = (main_df_weights['Nifty50_pct_change'] + 1).cumprod() # get cummulative returns
                    main_df_weights['portfolio_cummulative_return'] = (main_df_weights['portfolio_return'] + 1).cumprod() # get cummulative returns

                    """"""
                    #   """ Normalization """
                    main_df_weights['Normalization_portfolio_return'] =main_df_weights['portfolio_return'] / holding_months
                    main_df_weights['Normalization_Nifty50_return'] =main_df_weights['Nifty50_pct_change'] / holding_months
                    main_df_weights['Normalization_portfolio_cummulative_return'] = (main_df_weights['Normalization_portfolio_return'] + 1).cumprod() # get cummulative returns
                    main_df_weights['Normalization_nifty_cummulative_return'] = (main_df_weights['Normalization_Nifty50_return'] + 1).cumprod() # get cummulative returns
                    #
                    """"""

                    storing_weights = pd.concat([storing_weights,main_df_weights]) # concat main dataframe with storing dataframe
                    BlackLittermanModel_results.loc[len(BlackLittermanModel_results)] = [returns_method.__name__,risk_model,weight_mrthod,main_df_weights['portfolio_cummulative_return'].iloc[-1],main_df_weights['nifty_cummulative_return'].iloc[-1],returns_months,holding_months,dates,len(dates)] # insert data into all methods dataframe
            storing_weights.to_csv('Results/BlackLittermanModel/BlackLittermanModel_' + returns_method.__name__ + '_' + risk_model + '_' + weight_mrthod + '.csv',index=False) # save main dataframe
        BlackLittermanModel_results.to_csv('AllResultsBlackLitterman.csv',index=False) # save all methods dataframe
# Out:
# start mean_historical_return sample_cov bl_weights 6 6 188
# mean_historical_return sample_cov bl_weights 2010-01-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-02-26 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-07-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-10-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2010-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-04-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-07-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-08-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2011-12-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-02-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-03-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-06-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-09-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2012-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-03-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-06-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-08-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-11-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2013-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-05-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-08-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-11-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2014-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-01-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-02-27 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-05-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-10-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2015-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-01-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-04-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-07-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-10-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2016-12-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-04-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-09-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2017-12-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-06-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-09-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2018-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-03-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-06-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-08-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-11-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2019-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-05-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-10-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-11-27 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2020-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-01-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-02-26 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-04-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-07-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-10-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2021-12-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-04-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-07-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-08-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-09-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2022-12-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-02-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-03-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-04-28 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-05-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-06-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-07-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-08-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-09-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-10-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-11-30 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2023-12-29 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2024-01-31 Providing a view on an asset not in the universe
# mean_historical_return sample_cov bl_weights 2024-02-29 Providing a view on an asset not in the universe
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14900\3946922238.py in <module>
#      51
#      52                     for symbol in symbols[:-1]:
# ---> 53                         main_df_weights[symbol + '_multiply'] = main_df_weights[symbol + '_weights'] * main_df_weights[symbol + '_pct_change'] # multiply weights with returns
#      54                     main_df_weights['portfolio_return'] = main_df_weights[[i + '_multiply' for i in symbols[:-1]]].mean(axis=1) # get portfolio returns
#      55
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    4092
#    4093         if len(value.columns) != 1:
# -> 4094             raise ValueError(
#    4095                 "Cannot set a DataFrame with multiple columns to the single "
#    4096                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column HDFCBANK.NS_multiply

# %%
# create a folder to store results
if not os.path.exists('Results/EfficientFrontier'):
    os.makedirs('Results/EfficientFrontier')

EfficientFrontier_results = pd.DataFrame(columns=['returns_method','risk_model','weight_method','portfolio_return','nifty_return','return_months','holding_month','error_dates','no_of_error_dates'])
# EfficientFrontier_results = pd.read_csv('AllResults.csv')

# create a list of columns
column = ['Date','month_year','holding_months','returns_months']
column = column + [i + '_weights' for i in symbols[:-1]] + [i + '_pct_change' for i in symbols]

list_of_dates = ['2011-02-28','2016-02-29','2018-03-28']

# create a list of returns methods, risk models and weight methods
returns_methods = [mean_historical_return,ema_historical_return,capm_return]
risk_models_methods = ['sample_cov','semicovariance','exp_cov','ledoit_wolf','ledoit_wolf_single_factor','ledoit_wolf_constant_correlation','oracle_approximating']
method =['max_sharpe','min_volatility','efficient_risk','efficient_return','max_quadratic_utility']

# get oputput for each method in method list and each risk model in risk_models_methods list and each return in returns list
for returns_method in returns_methods: # loop through returns methods
    for risk_model in risk_models_methods: # loop through risk models
        for weight_mrthod in method: # loop through weight methods
            storing_weights = pd.DataFrame(columns=column) # create a storing dataframe
            for returns_months in range(6,0,-1): # loop through returns months
                for holding_months in range(6,0,-1): # loop through holding months
                    main_df_weights = pd.DataFrame(columns=column) # create a main dataframe
                    dates=[] # create a list to store error dates
                    print('start',returns_method.__name__,risk_model,weight_mrthod,returns_months,holding_months,len(sd))
                    for ind in range(12,len(sd)-(holding_months)): # loop through each row in dataframe
                        if sd['Date'][ind] not in list_of_dates: # check if date is not in list of dates
                            # print(sd['Date'][ind-returns_months],sd['Date'][ind])
                            df = sd1[(sd1['Date'] <= sd['Date'][ind]) & (sd1['Date'] >= sd['Date'][ind-returns_months])][symbols[:-1]] # get dataframe for return months
                            try:
                                mu = returns_method(df) # get returns using returns method
                                S = risk_matrix(df, method=risk_model) # get risk matrix using risk model
                                # get weights using max sharpe ratio in 0 to 1 range
                                ef = EfficientFrontier(mu, S) # create an object of EfficientFrontier
                                raw_weights = getattr(ef, weight_mrthod)() # get weights using weight method
                                cleaned_weights = ef.clean_weights() # get cleaned weights
                            except Exception as e:
                                print(returns_method.__name__,risk_model,weight_mrthod,sd['Date'][ind],e) # print error
                                dates.append(sd['Date'][ind])  # append error date to list
                                continue
                            cleaned_weights = pd.DataFrame.from_dict(cleaned_weights, orient='index', columns=['weights']) # convert cleaned weights to dataframe
                            cleaned_weights[cleaned_weights['weights'] < 0] = 0 # set negative weights to 0
                            cleaned_weights[cleaned_weights['weights'] > 0] = cleaned_weights[cleaned_weights['weights'] > 0] / cleaned_weights[cleaned_weights['weights'] > 0].sum() # normalize weights
                            returns_df = pd.DataFrame(columns=symbols) # create a returns dataframe
                            returns_df.loc[0] = sd[sd['Date'] == sd['Date'][ind]][symbols].iloc[0] # get returns starting date
                            returns_df.loc[1] = sd[sd['Date'] == sd['Date'][ind+holding_months]][symbols].iloc[0] # get returns ending date
                            main_df_weights.loc[len(main_df_weights)] = [sd['Date'][ind],sd['month_year'][ind],str(returns_months),str(holding_months),] + cleaned_weights['weights'].tolist() + returns_df.pct_change().iloc[1].tolist() # insert data into main dataframe

                    for symbol in symbols[:-1]:
                        main_df_weights[symbol + '_multiply'] = main_df_weights[symbol + '_weights'] * main_df_weights[symbol + '_pct_change'] # multiply weights with returns
                    main_df_weights['portfolio_return'] = main_df_weights[[i + '_multiply' for i in symbols[:-1]]].mean(axis=1) # get portfolio returns

                    main_df_weights['nifty_cummulative_return'] = (main_df_weights['Nifty50_pct_change'] + 1).cumprod() # get nifty_cummulative_return
                    main_df_weights['portfolio_cummulative_return'] = (main_df_weights['portfolio_return'] + 1).cumprod() # get portfolio_cummulative_return

                    """"""
                    #    """ Normalization """
                    main_df_weights['Normalization_portfolio_return'] =main_df_weights['portfolio_return'] / holding_months
                    main_df_weights['Normalization_Nifty50_return'] =main_df_weights['Nifty50_pct_change'] / holding_months
                    main_df_weights['Normalization_portfolio_cummulative_return'] = (main_df_weights['Normalization_portfolio_return'] + 1).cumprod()
                    main_df_weights['Normalization_nifty_cummulative_return'] = (main_df_weights['Normalization_Nifty50_return'] + 1).cumprod()
                    #
                    """"""
                    storing_weights = pd.concat([storing_weights,main_df_weights],axis=0) # concat main dataframe to storing dataframe

                    EfficientFrontier_results.loc[len(EfficientFrontier_results)] = [returns_method.__name__,risk_model,weight_mrthod,main_df_weights['portfolio_cummulative_return'].iloc[-1],main_df_weights['nifty_cummulative_return'].iloc[-1],returns_months,holding_months,dates,len(dates)]
            storing_weights.to_csv('Results/EfficientFrontier/EfficientFrontier_'+returns_method.__name__+'_'+risk_model+'_'+weight_mrthod+'.csv',index=False) # save storing dataframe to csv
        EfficientFrontier_results.to_csv('AllResults_EfficientFrontier.csv',index=False) # save storing dataframe to csv
# Out:
# start mean_historical_return sample_cov max_sharpe 6 6 188
# mean_historical_return sample_cov max_sharpe 2010-01-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-02-26 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-07-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-10-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2010-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-04-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-07-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-08-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2011-12-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-02-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-03-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-06-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-09-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2012-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-03-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-06-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-08-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-11-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2013-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-05-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-08-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-11-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2014-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-01-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-02-27 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-05-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-08-31 at least one of the assets must have an expected return exceeding the risk-free rate
# mean_historical_return sample_cov max_sharpe 2015-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-10-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2015-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-01-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-04-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-07-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-10-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2016-12-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-04-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-09-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2017-12-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-06-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-09-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2018-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-03-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-06-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-08-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-11-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2019-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-05-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-10-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-11-27 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2020-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-01-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-02-26 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-04-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-07-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-10-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2021-12-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-04-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-07-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-08-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-09-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2022-12-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-02-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-03-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-04-28 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-05-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-06-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-07-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-08-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-09-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-10-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-11-30 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2023-12-29 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2024-01-31 Quadratic form matrices must be symmetric/Hermitian.
# mean_historical_return sample_cov max_sharpe 2024-02-29 Quadratic form matrices must be symmetric/Hermitian.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nifty50_pct_change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14900\156155201.py in <module>
#      54                     main_df_weights['portfolio_return'] = main_df_weights[[i + '_multiply' for i in symbols[:-1]]].mean(axis=1) # get portfolio returns
#      55
# ---> 56                     main_df_weights['nifty_cummulative_return'] = (main_df_weights['Nifty50_pct_change'] + 1).cumprod() # get nifty_cummulative_return
#      57                     main_df_weights['portfolio_cummulative_return'] = (main_df_weights['portfolio_return'] + 1).cumprod() # get portfolio_cummulative_return
#      58
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Nifty50_pct_change'

# %%
EfficientFrontier_results
# Out:
# Empty DataFrame
# Columns: [returns_method, risk_model, weight_method, portfolio_return, nifty_return, return_months, holding_month, error_dates, no_of_error_dates]
# Index: []

# %%
BlackLittermanModel_results
# Out:
# Empty DataFrame
# Columns: [returns_method, risk_model, weight_method, portfolio_return, nifty_return, return_months, holding_month, error_dates, no_of_error_dates]
# Index: []

# %%
import shutil
shutil.make_archive('EfficientFrontier', 'zip', 'Results/EfficientFrontier')
shutil.make_archive('BlackLittermanModel', 'zip', 'Results/BlackLittermanModel')
# Out:
# 'C:\\Users\\admin\\BlackLittermanModel.zip'
