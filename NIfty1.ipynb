# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# %%
#collect and clean the data
sd = yf.download("^NSEI", interval='1d')
df=sd
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2023-10-20  19542.150391  19593.800781  19518.699219  19542.650391
# 2023-10-23  19521.599609  19556.849609  19257.849609  19281.750000
# 2023-10-25  19286.449219  19347.300781  19074.150391  19122.150391
# 2023-10-26  19027.250000  19041.699219  18837.849609  18857.250000
# 2023-10-27  18928.750000  19076.150391  18926.650391  19047.250000
#
#                Adj Close  Volume
# Date
# 2007-09-17   4494.649902       0
# 2007-09-18   4546.200195       0
# 2007-09-19   4732.350098       0
# 2007-09-20   4747.549805       0
# 2007-09-21   4837.549805       0
# ...                  ...     ...
# 2023-10-20  19542.650391  198300
# 2023-10-23  19281.750000  176000
# 2023-10-25  19122.150391  225300
# 2023-10-26  18857.250000  300400
# 2023-10-27  19047.250000  205200
#
# [3950 rows x 6 columns]

# %%
df.plot(y="Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Train the model
X= df[["Open","High","Low","Volume"]]
X= X[:int(len(df)-1)]
y=df["Close"]
y= y[:int(len(df)-1)]
# Out:
#                     Open          High           Low  Volume
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098       0
# 2007-09-18   4494.100098   4551.799805   4481.549805       0
# 2007-09-19   4550.250000   4739.000000   4550.250000       0
# 2007-09-20   4734.850098   4760.850098   4721.149902       0
# 2007-09-21   4752.950195   4855.700195   4733.700195       0
# ...                  ...           ...           ...     ...
# 2023-10-19  19545.199219  19681.800781  19512.349609  230300
# 2023-10-20  19542.150391  19593.800781  19518.699219  198300
# 2023-10-23  19521.599609  19556.849609  19257.849609  176000
# 2023-10-25  19286.449219  19347.300781  19074.150391  225300
# 2023-10-26  19027.250000  19041.699219  18837.849609  300400
#
# [3949 rows x 4 columns]

# %%
model = RandomForestRegressor()

# %%
model.fit(X,y)
# Out:
# RandomForestRegressor()

# %%
#Test the model
predictions = model.predict(X)
print("The model score is:", model.score(X,y))
# Out:
# The model score is: 0.9999822615613276

# %%
new_data = df[["Open","High","Low","Volume"]].tail(1)
prediction = model.predict(new_data)
print("Thye model predicts the last row or day to be :", prediction)
# Out:
# Thye model predicts the last row or day to be : [18927.86177734]

# %% [markdown]
# new_data = df[["Open","High","Low","Volume"]]
# prediction = model.predict(new_data)

# %%
new_data = df[["Open","High","Low","Volume"]].tail(2)
prediction = model.predict(new_data)
prediction
# Out:
# array([18892.97294922, 18927.86177734])

# %%
ret_daily = df["Close"].pct_change(periods=1)
ret_daily
# Out:
# Date
# 2007-09-17         NaN
# 2007-09-18    0.011469
# 2007-09-19    0.040946
# 2007-09-20    0.003212
# 2007-09-21    0.018957
#                 ...
# 2023-10-20   -0.004181
# 2023-10-23   -0.013350
# 2023-10-25   -0.008277
# 2023-10-26   -0.013853
# 2023-10-27    0.010076
# Name: Close, Length: 3950, dtype: float64

# %%
sd = yf.download("^IXIC", interval='1d')
nsdq=sd
nsdq
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 1971-02-05    100.000000    100.000000    100.000000    100.000000
# 1971-02-08    100.839996    100.839996    100.839996    100.839996
# 1971-02-09    100.760002    100.760002    100.760002    100.760002
# 1971-02-10    100.690002    100.690002    100.690002    100.690002
# 1971-02-11    101.449997    101.449997    101.449997    101.449997
# ...                  ...           ...           ...           ...
# 2023-10-23  12930.849609  13143.219727  12848.830078  13018.330078
# 2023-10-24  13084.990234  13170.389648  13022.849609  13139.870117
# 2023-10-25  13039.860352  13042.519531  12804.299805  12821.219727
# 2023-10-26  12768.969727  12818.139648  12543.860352  12595.610352
# 2023-10-27  12718.690430  12772.429688  12600.570312  12643.009766
#
#                Adj Close      Volume
# Date
# 1971-02-05    100.000000           0
# 1971-02-08    100.839996           0
# 1971-02-09    100.760002           0
# 1971-02-10    100.690002           0
# 1971-02-11    101.449997           0
# ...                  ...         ...
# 2023-10-23  13018.330078  4669060000
# 2023-10-24  13139.870117  4604720000
# 2023-10-25  12821.219727  4599850000
# 2023-10-26  12595.610352  4894900000
# 2023-10-27  12643.009766  4172100000
#
# [13298 rows x 6 columns]

# %%
nsdq_ret = nsdq["Close"].pct_change(periods=1)
nsdq_ret
# Out:
# Date
# 1971-02-05         NaN
# 1971-02-08    0.008400
# 1971-02-09   -0.000793
# 1971-02-10   -0.000695
# 1971-02-11    0.007548
#                 ...
# 2023-10-23    0.002659
# 2023-10-24    0.009336
# 2023-10-25   -0.024251
# 2023-10-26   -0.017597
# 2023-10-27    0.003763
# Name: Close, Length: 13298, dtype: float64

# %%
#nsdq_ret.drop(columns="Date",inplace =False)
#nsdq_ret.drop(columns=nsdq_ret['date'], inplace=True)
nsdq_ret.drop(columns=nsdq_ret.columns[1:1], inplace=True)
nsdq_ret
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15428\1369039838.py in <module>
#       1 #nsdq_ret.drop(columns="Date",inplace =False)
#       2 #nsdq_ret.drop(columns=nsdq_ret['date'], inplace=True)
# ----> 3 nsdq_ret.drop(columns=nsdq_ret.columns[1:1], inplace=True)
#       4 nsdq_ret
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
nsdq_ret.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
nsdq_vol = np.std(nsdq_ret)
nsdq_volroll=nsdq_ret.rolling(window=60).std()
nsdq_volroll
nsdq_volroll.plot()
#numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<no value>, *, where=<no value>)
# Out:
# <AxesSubplot:xlabel='Date'>
