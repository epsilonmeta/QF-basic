# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import yfinance as yf
import random
import os
import matplotlib.pyplot as plt
from datetime import datetime as dt
import datetime as date
plt.rcParams["figure.figsize"] = (20,10)
import seaborn as sn
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier

# %%
cwd = os.getcwd() + "\\ind_nifty50list.csv"
symbol= pd.read_csv(cwd)
symbol["NS"]= ".NS"
symbol["ticker"] = symbol["Symbol"] + symbol["NS"]
symbol
# Out:
#                                           Company Name  \
# 0                                       ABB India Ltd.
# 1                          Adani Energy Solutions Ltd.
# 2                               Adani Enterprises Ltd.
# 3                              Adani Green Energy Ltd.
# 4           Adani Ports and Special Economic Zone Ltd.
# 5                                     Adani Power Ltd.
# 6                                 Adani Total Gas Ltd.
# 7                                  Ambuja Cements Ltd.
# 8                     Apollo Hospitals Enterprise Ltd.
# 9                                    Asian Paints Ltd.
# 10                              Avenue Supermarts Ltd.
# 11                                      Axis Bank Ltd.
# 12                                     Bajaj Auto Ltd.
# 13                                  Bajaj Finance Ltd.
# 14                                  Bajaj Finserv Ltd.
# 15                    Bajaj Holdings & Investment Ltd.
# 16                                      Bank of Baroda
# 17                            Berger Paints India Ltd.
# 18                             Bharat Electronics Ltd.
# 19                   Bharat Petroleum Corporation Ltd.
# 20                                  Bharti Airtel Ltd.
# 21                                          Bosch Ltd.
# 22                           Britannia Industries Ltd.
# 23                                         Canara Bank
# 24   Cholamandalam Investment and Finance Company Ltd.
# 25                                          Cipla Ltd.
# 26                                     Coal India Ltd.
# 27                      Colgate Palmolive (India) Ltd.
# 28                                            DLF Ltd.
# 29                                    Dabur India Ltd.
# 30                            Divi's Laboratories Ltd.
# 31                       Dr. Reddy's Laboratories Ltd.
# 32                                  Eicher Motors Ltd.
# 33                                   GAIL (India) Ltd.
# 34                       Godrej Consumer Products Ltd.
# 35                              Grasim Industries Ltd.
# 36                               HCL Technologies Ltd.
# 37                                      HDFC Bank Ltd.
# 38                    HDFC Life Insurance Company Ltd.
# 39                                  Havells India Ltd.
# 40                                  Hero MotoCorp Ltd.
# 41                            Hindalco Industries Ltd.
# 42                          Hindustan Aeronautics Ltd.
# 43                             Hindustan Unilever Ltd.
# 44                                     ICICI Bank Ltd.
# 45        ICICI Lombard General Insurance Company Ltd.
# 46        ICICI Prudential Life Insurance Company Ltd.
# 47                                            ITC Ltd.
# 48                         Indian Oil Corporation Ltd.
# 49   Indian Railway Catering And Tourism Corporatio...
# 50             Indian Railway Finance Corporation Ltd.
# 51                                  IndusInd Bank Ltd.
# 52                              Info Edge (India) Ltd.
# 53                                        Infosys Ltd.
# 54                            InterGlobe Aviation Ltd.
# 55                                      JSW Steel Ltd.
# 56                           Jindal Steel & Power Ltd.
# 57                         Jio Financial Services Ltd.
# 58                            Kotak Mahindra Bank Ltd.
# 59                                    LTIMindtree Ltd.
# 60                                Larsen & Toubro Ltd.
# 61                 Life Insurance Corporation of India
# 62                            Mahindra & Mahindra Ltd.
# 63                                         Marico Ltd.
# 64                            Maruti Suzuki India Ltd.
# 65                                           NTPC Ltd.
# 66                                   Nestle India Ltd.
# 67                  Oil & Natural Gas Corporation Ltd.
# 68                            Pidilite Industries Ltd.
# 69                      Power Finance Corporation Ltd.
# 70                Power Grid Corporation of India Ltd.
# 71                                Punjab National Bank
# 72                                            REC Ltd.
# 73                            Reliance Industries Ltd.
# 74                 SBI Cards and Payment Services Ltd.
# 75                     SBI Life Insurance Company Ltd.
# 76                                            SRF Ltd.
# 77            Samvardhana Motherson International Ltd.
# 78                                   Shree Cement Ltd.
# 79                                Shriram Finance Ltd.
# 80                                        Siemens Ltd.
# 81                                 State Bank of India
# 82                  Sun Pharmaceutical Industries Ltd.
# 83                              TVS Motor Company Ltd.
# 84                      Tata Consultancy Services Ltd.
# 85                         Tata Consumer Products Ltd.
# 86                                 Tata Motors Ltd DVR
# 87                                    Tata Motors Ltd.
# 88                                 Tata Power Co. Ltd.
# 89                                     Tata Steel Ltd.
# 90                                  Tech Mahindra Ltd.
# 91                                  Titan Company Ltd.
# 92                        Torrent Pharmaceuticals Ltd.
# 93                                          Trent Ltd.
# 94                               UltraTech Cement Ltd.
# 95                                 United Spirits Ltd.
# 96                                Varun Beverages Ltd.
# 97                                        Vedanta Ltd.
# 98                                          Wipro Ltd.
# 99                                         Zomato Ltd.
# 100                            Zydus Lifesciences Ltd.
#
#                            Industry      Symbol Series     ISIN Code   NS  \
# 0                     Capital Goods         ABB     EQ  INE117A01022  .NS
# 1                             Power  ADANIENSOL     EQ  INE931S01010  .NS
# 2                   Metals & Mining    ADANIENT     EQ  INE423A01024  .NS
# 3                             Power  ADANIGREEN     EQ  INE364U01010  .NS
# 4                          Services  ADANIPORTS     EQ  INE742F01042  .NS
# 5                             Power  ADANIPOWER     EQ  INE814H01011  .NS
# 6        Oil Gas & Consumable Fuels        ATGL     EQ  INE399L01023  .NS
# 7            Construction Materials   AMBUJACEM     EQ  INE079A01024  .NS
# 8                        Healthcare  APOLLOHOSP     EQ  INE437A01024  .NS
# 9                 Consumer Durables  ASIANPAINT     EQ  INE021A01026  .NS
# 10                Consumer Services       DMART     EQ  INE192R01011  .NS
# 11               Financial Services    AXISBANK     EQ  INE238A01034  .NS
# 12   Automobile and Auto Components  BAJAJ-AUTO     EQ  INE917I01010  .NS
# 13               Financial Services  BAJFINANCE     EQ  INE296A01024  .NS
# 14               Financial Services  BAJAJFINSV     EQ  INE918I01026  .NS
# 15               Financial Services  BAJAJHLDNG     EQ  INE118A01012  .NS
# 16               Financial Services  BANKBARODA     EQ  INE028A01039  .NS
# 17                Consumer Durables  BERGEPAINT     EQ  INE463A01038  .NS
# 18                    Capital Goods         BEL     EQ  INE263A01024  .NS
# 19       Oil Gas & Consumable Fuels        BPCL     EQ  INE029A01011  .NS
# 20                Telecommunication  BHARTIARTL     EQ  INE397D01024  .NS
# 21   Automobile and Auto Components    BOSCHLTD     EQ  INE323A01026  .NS
# 22       Fast Moving Consumer Goods   BRITANNIA     EQ  INE216A01030  .NS
# 23               Financial Services       CANBK     EQ  INE476A01022  .NS
# 24               Financial Services    CHOLAFIN     EQ  INE121A01024  .NS
# 25                       Healthcare       CIPLA     EQ  INE059A01026  .NS
# 26       Oil Gas & Consumable Fuels   COALINDIA     EQ  INE522F01014  .NS
# 27       Fast Moving Consumer Goods      COLPAL     EQ  INE259A01022  .NS
# 28                           Realty         DLF     EQ  INE271C01023  .NS
# 29       Fast Moving Consumer Goods       DABUR     EQ  INE016A01026  .NS
# 30                       Healthcare    DIVISLAB     EQ  INE361B01024  .NS
# 31                       Healthcare     DRREDDY     EQ  INE089A01023  .NS
# 32   Automobile and Auto Components   EICHERMOT     EQ  INE066A01021  .NS
# 33       Oil Gas & Consumable Fuels        GAIL     EQ  INE129A01019  .NS
# 34       Fast Moving Consumer Goods    GODREJCP     EQ  INE102D01028  .NS
# 35           Construction Materials      GRASIM     EQ  INE047A01021  .NS
# 36           Information Technology     HCLTECH     EQ  INE860A01027  .NS
# 37               Financial Services    HDFCBANK     EQ  INE040A01034  .NS
# 38               Financial Services    HDFCLIFE     EQ  INE795G01014  .NS
# 39                Consumer Durables     HAVELLS     EQ  INE176B01034  .NS
# 40   Automobile and Auto Components  HEROMOTOCO     EQ  INE158A01026  .NS
# 41                  Metals & Mining    HINDALCO     EQ  INE038A01020  .NS
# 42                    Capital Goods         HAL     EQ  INE066F01020  .NS
# 43       Fast Moving Consumer Goods  HINDUNILVR     EQ  INE030A01027  .NS
# 44               Financial Services   ICICIBANK     EQ  INE090A01021  .NS
# 45               Financial Services     ICICIGI     EQ  INE765G01017  .NS
# 46               Financial Services  ICICIPRULI     EQ  INE726G01019  .NS
# 47       Fast Moving Consumer Goods         ITC     EQ  INE154A01025  .NS
# 48       Oil Gas & Consumable Fuels         IOC     EQ  INE242A01010  .NS
# 49                Consumer Services       IRCTC     EQ  INE335Y01020  .NS
# 50               Financial Services        IRFC     EQ  INE053F01010  .NS
# 51               Financial Services  INDUSINDBK     EQ  INE095A01012  .NS
# 52                Consumer Services      NAUKRI     EQ  INE663F01024  .NS
# 53           Information Technology        INFY     EQ  INE009A01021  .NS
# 54                         Services      INDIGO     EQ  INE646L01027  .NS
# 55                  Metals & Mining    JSWSTEEL     EQ  INE019A01038  .NS
# 56                  Metals & Mining  JINDALSTEL     EQ  INE749A01030  .NS
# 57               Financial Services      JIOFIN     EQ  INE758E01017  .NS
# 58               Financial Services   KOTAKBANK     EQ  INE237A01028  .NS
# 59           Information Technology        LTIM     EQ  INE214T01019  .NS
# 60                     Construction          LT     EQ  INE018A01030  .NS
# 61               Financial Services        LICI     EQ  INE0J1Y01017  .NS
# 62   Automobile and Auto Components         M&M     EQ  INE101A01026  .NS
# 63       Fast Moving Consumer Goods      MARICO     EQ  INE196A01026  .NS
# 64   Automobile and Auto Components      MARUTI     EQ  INE585B01010  .NS
# 65                            Power        NTPC     EQ  INE733E01010  .NS
# 66       Fast Moving Consumer Goods   NESTLEIND     EQ  INE239A01024  .NS
# 67       Oil Gas & Consumable Fuels        ONGC     EQ  INE213A01029  .NS
# 68                        Chemicals  PIDILITIND     EQ  INE318A01026  .NS
# 69               Financial Services         PFC     EQ  INE134E01011  .NS
# 70                            Power   POWERGRID     EQ  INE752E01010  .NS
# 71               Financial Services         PNB     EQ  INE160A01022  .NS
# 72               Financial Services      RECLTD     EQ  INE020B01018  .NS
# 73       Oil Gas & Consumable Fuels    RELIANCE     EQ  INE002A01018  .NS
# 74               Financial Services     SBICARD     EQ  INE018E01016  .NS
# 75               Financial Services     SBILIFE     EQ  INE123W01016  .NS
# 76                        Chemicals         SRF     EQ  INE647A01010  .NS
# 77   Automobile and Auto Components   MOTHERSON     EQ  INE775A01035  .NS
# 78           Construction Materials    SHREECEM     EQ  INE070A01015  .NS
# 79               Financial Services  SHRIRAMFIN     EQ  INE721A01013  .NS
# 80                    Capital Goods     SIEMENS     EQ  INE003A01024  .NS
# 81               Financial Services        SBIN     EQ  INE062A01020  .NS
# 82                       Healthcare   SUNPHARMA     EQ  INE044A01036  .NS
# 83   Automobile and Auto Components    TVSMOTOR     EQ  INE494B01023  .NS
# 84           Information Technology         TCS     EQ  INE467B01029  .NS
# 85       Fast Moving Consumer Goods  TATACONSUM     EQ  INE192A01025  .NS
# 86   Automobile and Auto Components  TATAMTRDVR     EQ  IN9155A01020  .NS
# 87   Automobile and Auto Components  TATAMOTORS     EQ  INE155A01022  .NS
# 88                            Power   TATAPOWER     EQ  INE245A01021  .NS
# 89                  Metals & Mining   TATASTEEL     EQ  INE081A01020  .NS
# 90           Information Technology       TECHM     EQ  INE669C01036  .NS
# 91                Consumer Durables       TITAN     EQ  INE280A01028  .NS
# 92                       Healthcare  TORNTPHARM     EQ  INE685A01028  .NS
# 93                Consumer Services       TRENT     EQ  INE849A01020  .NS
# 94           Construction Materials  ULTRACEMCO     EQ  INE481G01011  .NS
# 95       Fast Moving Consumer Goods    UNITDSPR     EQ  INE854D01024  .NS
# 96       Fast Moving Consumer Goods         VBL     EQ  INE200M01021  .NS
# 97                  Metals & Mining        VEDL     EQ  INE205A01025  .NS
# 98           Information Technology       WIPRO     EQ  INE075A01022  .NS
# 99                Consumer Services      ZOMATO     EQ  INE758T01015  .NS
# 100                      Healthcare   ZYDUSLIFE     EQ  INE010B01027  .NS
#
#             ticker
# 0           ABB.NS
# 1    ADANIENSOL.NS
# 2      ADANIENT.NS
# 3    ADANIGREEN.NS
# 4    ADANIPORTS.NS
# 5    ADANIPOWER.NS
# 6          ATGL.NS
# 7     AMBUJACEM.NS
# 8    APOLLOHOSP.NS
# 9    ASIANPAINT.NS
# 10        DMART.NS
# 11     AXISBANK.NS
# 12   BAJAJ-AUTO.NS
# 13   BAJFINANCE.NS
# 14   BAJAJFINSV.NS
# 15   BAJAJHLDNG.NS
# 16   BANKBARODA.NS
# 17   BERGEPAINT.NS
# 18          BEL.NS
# 19         BPCL.NS
# 20   BHARTIARTL.NS
# 21     BOSCHLTD.NS
# 22    BRITANNIA.NS
# 23        CANBK.NS
# 24     CHOLAFIN.NS
# 25        CIPLA.NS
# 26    COALINDIA.NS
# 27       COLPAL.NS
# 28          DLF.NS
# 29        DABUR.NS
# 30     DIVISLAB.NS
# 31      DRREDDY.NS
# 32    EICHERMOT.NS
# 33         GAIL.NS
# 34     GODREJCP.NS
# 35       GRASIM.NS
# 36      HCLTECH.NS
# 37     HDFCBANK.NS
# 38     HDFCLIFE.NS
# 39      HAVELLS.NS
# 40   HEROMOTOCO.NS
# 41     HINDALCO.NS
# 42          HAL.NS
# 43   HINDUNILVR.NS
# 44    ICICIBANK.NS
# 45      ICICIGI.NS
# 46   ICICIPRULI.NS
# 47          ITC.NS
# 48          IOC.NS
# 49        IRCTC.NS
# 50         IRFC.NS
# 51   INDUSINDBK.NS
# 52       NAUKRI.NS
# 53         INFY.NS
# 54       INDIGO.NS
# 55     JSWSTEEL.NS
# 56   JINDALSTEL.NS
# 57       JIOFIN.NS
# 58    KOTAKBANK.NS
# 59         LTIM.NS
# 60           LT.NS
# 61         LICI.NS
# 62          M&M.NS
# 63       MARICO.NS
# 64       MARUTI.NS
# 65         NTPC.NS
# 66    NESTLEIND.NS
# 67         ONGC.NS
# 68   PIDILITIND.NS
# 69          PFC.NS
# 70    POWERGRID.NS
# 71          PNB.NS
# 72       RECLTD.NS
# 73     RELIANCE.NS
# 74      SBICARD.NS
# 75      SBILIFE.NS
# 76          SRF.NS
# 77    MOTHERSON.NS
# 78     SHREECEM.NS
# 79   SHRIRAMFIN.NS
# 80      SIEMENS.NS
# 81         SBIN.NS
# 82    SUNPHARMA.NS
# 83     TVSMOTOR.NS
# 84          TCS.NS
# 85   TATACONSUM.NS
# 86   TATAMTRDVR.NS
# 87   TATAMOTORS.NS
# 88    TATAPOWER.NS
# 89    TATASTEEL.NS
# 90        TECHM.NS
# 91        TITAN.NS
# 92   TORNTPHARM.NS
# 93        TRENT.NS
# 94   ULTRACEMCO.NS
# 95     UNITDSPR.NS
# 96          VBL.NS
# 97         VEDL.NS
# 98        WIPRO.NS
# 99       ZOMATO.NS
# 100   ZYDUSLIFE.NS

# %%
pricechg = symbol["Symbol"] + " pricechg"
percentchg = symbol["Symbol"] #+ " percentchg"
ticker = symbol['ticker']
pricechg= pricechg.values.tolist()
percentchg= percentchg.values.tolist()
ticker= ticker.values.tolist()
ticker
#symbols= ['RELIANCE.NS','HDFCBANK.NS','ICICIBANK.NS','HDFCBANK.NS','INFY.NS','ITC.NS','TCS.NS','HINDUNILVR.NS','SBIN.NS','BHARTIARTL.NS', ]
#df = yf.download(symbols, interval='1d')['Close']
#returns_df = df.pct_change(1)
#prices_df = yf.download(tickers, start, end)['Adj Close']
# Out:
# ['ABB.NS',
#  'ADANIENSOL.NS',
#  'ADANIENT.NS',
#  'ADANIGREEN.NS',
#  'ADANIPORTS.NS',
#  'ADANIPOWER.NS',
#  'ATGL.NS',
#  'AMBUJACEM.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'DMART.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BAJAJHLDNG.NS',
#  'BANKBARODA.NS',
#  'BERGEPAINT.NS',
#  'BEL.NS',
#  'BPCL.NS',
#  'BHARTIARTL.NS',
#  'BOSCHLTD.NS',
#  'BRITANNIA.NS',
#  'CANBK.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'COLPAL.NS',
#  'DLF.NS',
#  'DABUR.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GAIL.NS',
#  'GODREJCP.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HAVELLS.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HAL.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'ICICIGI.NS',
#  'ICICIPRULI.NS',
#  'ITC.NS',
#  'IOC.NS',
#  'IRCTC.NS',
#  'IRFC.NS',
#  'INDUSINDBK.NS',
#  'NAUKRI.NS',
#  'INFY.NS',
#  'INDIGO.NS',
#  'JSWSTEEL.NS',
#  'JINDALSTEL.NS',
#  'JIOFIN.NS',
#  'KOTAKBANK.NS',
#  'LTIM.NS',
#  'LT.NS',
#  'LICI.NS',
#  'M&M.NS',
#  'MARICO.NS',
#  'MARUTI.NS',
#  'NTPC.NS',
#  'NESTLEIND.NS',
#  'ONGC.NS',
#  'PIDILITIND.NS',
#  'PFC.NS',
#  'POWERGRID.NS',
#  'PNB.NS',
#  'RECLTD.NS',
#  'RELIANCE.NS',
#  'SBICARD.NS',
#  'SBILIFE.NS',
#  'SRF.NS',
#  'MOTHERSON.NS',
#  'SHREECEM.NS',
#  'SHRIRAMFIN.NS',
#  'SIEMENS.NS',
#  'SBIN.NS',
#  'SUNPHARMA.NS',
#  'TVSMOTOR.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TATAMTRDVR.NS',
#  'TATAMOTORS.NS',
#  'TATAPOWER.NS',
#  'TATASTEEL.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'TORNTPHARM.NS',
#  'TRENT.NS',
#  'ULTRACEMCO.NS',
#  'UNITDSPR.NS',
#  'VBL.NS',
#  'VEDL.NS',
#  'WIPRO.NS',
#  'ZOMATO.NS',
#  'ZYDUSLIFE.NS']

# %%
sd = yf.download(ticker, interval='1d')
#data= sd['Adj Close']
#data
# Out:
# Exception in thread Thread-222:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**                     5%                       ]  5 of 101 completed
# Exception in thread Thread-227:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [******                13%                       ]  13 of 101 completed
# Exception in thread Thread-236:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [************          25%                       ]  25 of 101 completed
# Exception in thread Thread-249:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*************         28%                       ]  28 of 101 completed
# Exception in thread Thread-252:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
# Exception in thread Thread-254:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-253:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-256:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-257:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-258:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**************        30%                       ]  30 of 101 completed
# Exception in thread Thread-262:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
# Exception in thread Thread-261:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
# [***************       31%                       ]  31 of 101 completed
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*****************     36%                       ]  36 of 101 completed
# Exception in thread Thread-270:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*******************   40%                       ]  40 of 101 completed
# Exception in thread Thread-273:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************45%                       ]  45 of 101 completed
# Exception in thread Thread-280:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************47%                       ]  47 of 101 completed
# Exception in thread Thread-283:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************48%                       ]  48 of 101 completed
# Exception in thread Thread-284:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-285:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************51%                       ]  52 of 101 completed
# Exception in thread Thread-291:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
# Exception in thread Thread-290:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-292:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************52%                       ]  53 of 101 completed
# Exception in thread Thread-295:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
# Exception in thread Thread-296:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************53%                       ]  54 of 101 completed
# Exception in thread Thread-298:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************63%*****                  ]  64 of 101 completed
# Exception in thread Thread-308:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************65%******                 ]  66 of 101 completed
# Exception in thread Thread-312:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************73%**********             ]  74 of 101 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9300\2897333036.py in <module>
# ----> 1 sd = yf.download(ticker, interval='1d')
#       2 #data= sd['Adj Close']
#       3 #data
#
# ~\anaconda3\lib\site-packages\yfinance\multi.py in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     110                                    rounding=rounding, timeout=timeout)
#     111         while len(shared._DFS) < len(tickers):
# --> 112             _time.sleep(0.01)
#     113
#     114     # download synchronously
#
# KeyboardInterrupt:

# %% [markdown]
# Coding cell block below requires inputs as mentioned in the comments in the block

# %%
# This coding block requires inputs for each of the variables as described below-
# returnperiod- No. of months over which the returns of stocks is measured to create a portfolio
# holdingperiod- Following no. of months over which the stocks in the portfolio will be held for 
# sdate_input- Starting date from where the data for each stock should start (Starting date must fall on a Monday)
# fdate_input- Ending date for where the data for each stock should end (Ending date must fall on a Friday)
# input for dates should be in the following format -> "YYYY-MM-DD"
returnperiod= 3
holdingperiod= 6
sdate_input= "2021-1-4"
fdate_input= "2024-5-27"

# %%
start= dt.strptime(sdate_input, '%Y-%m-%d')
finish= dt.strptime(fdate_input,'%Y-%m-%d')

forw = df.loc[start:finish]
dailydf = df.loc[start:finish]
forw.reset_index(inplace=True)
forw['date_num'] = forw['Date'].dt.weekday
weeklydf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
weeklydfcopy = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
returndf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]

# %%
weeklydfcopy.set_index(np.arange(len(weeklydfcopy.index)), inplace=True, drop=True)

# %%
#Calculating return of stocks depending on the number of months input in "returnperiod" variable
#for creating porfolios 
for i,j in zip(returndf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = returndf.loc[i,"Date"] + date.timedelta(days=3)
            returndf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        returndf.loc[i+1,tick]= forw.loc[k,tick]
                        returndf.loc[i+1,"date_num"]=4
    
returndf.sort_index(inplace=True)
returndf.set_index(np.arange(1,len(returndf.index)+1,1),inplace=True, drop=True)

for i in returndf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        returndf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   returndf[j]=returndf[i]-returndf[i].shift(returnperiod*2-1)
   returndf[k]=returndf[j]/returndf[i].shift(returnperiod*2-1)*100
   
returndf = returndf[returndf["date_num"]==4]
returndf.set_index(np.arange(1,len(returndf.index)+1,1), inplace=True, drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ADANIENT.NS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16360\2770224468.py in <module>
#      12                 if forw.loc[k,"Date"]==d:
#      13                     for tick in ticker:
# ---> 14                         returndf.loc[i+1,tick]= forw.loc[k,tick]
#      15                         returndf.loc[i+1,"date_num"]=4
#      16
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1094             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095             if self._is_scalar_access(key):
# -> 1096                 return self.obj._get_value(*key, takeable=self._takeable)
#    1097             return self._getitem_tuple(key)
#    1098         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3868             return series._values[index]
#    3869
# -> 3870         series = self._get_item_cache(col)
#    3871         engine = self.index._engine
#    3872
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_item_cache(self, item)
#    4253             #  pending resolution of GH#33047
#    4254
# -> 4255             loc = self.columns.get_loc(item)
#    4256             res = self._ixs(loc, axis=1)
#    4257
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ADANIENT.NS'

# %%
#Portfolio formation
winner_portfolio= pd.DataFrame()
loser_portfolio= pd.DataFrame() 

# Portfolio of top 10 stocks made
for i in returndf.index:

    winner_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"]

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W1']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W2']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W3']= j
            returndf.loc[i,j]= None
    
    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W4']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W5']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W6']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W7']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W8']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W9']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W10']= j
            returndf.loc[i,j]= None

# Portfolio of bottom 10 stocks made
for i in returndf.index:

    loser_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"] 

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L1']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L2']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L3']= j
            returndf.loc[i,j]= None
    
    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L4']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L5']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L6']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L7']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L8']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L9']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L10']= j
            returndf.loc[i,j]= None


winner_portfolio.dropna(inplace=True)
winner_portfolio.reset_index(inplace=True)
del winner_portfolio["index"]

winner_weightage = pd.DataFrame()

winner_column_list=winner_portfolio.columns.values.tolist()
del winner_column_list[0]

loser_portfolio.dropna(inplace=True)
loser_portfolio.reset_index(inplace=True)
del loser_portfolio["index"]

loser_weightage = pd.DataFrame()

loser_column_list=loser_portfolio.columns.values.tolist()
del loser_column_list[0]

# %%
#Calculating weightage for winner portfolio using mean variance optimization
#To check the weightage dataframe print "winner_weightage" variable

for num in winner_portfolio.index:
    for d in dailydf.index:
        df = pd.DataFrame()
        if winner_portfolio.loc[num,"Date"] == d:
            list=winner_portfolio.loc[num,:].values.tolist()
            del list[0]
            for i in np.arange(len(list)):
                list[i]= list[i]+".NS"
            df = dailydf.loc[d- date.timedelta(days=70):d, list]
            mu = mean_historical_return(df)
            S = CovarianceShrinkage(df).ledoit_wolf()
            ef = EfficientFrontier(mu, S)#,weight_bounds=(-1,1))
            winner_weights = ef.max_sharpe()
            winner_cleaned_weights = ef.clean_weights()
            w=pd.Series(winner_cleaned_weights)
            for lm,ln in zip(list,winner_column_list):
                winner_weightage.loc[num,ln]= w[lm]

# %%
#Calculating return of stocks depending on the number of months input in "holdingperiod" variable
#for backtesting poertfolio returns

holdingdf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]

for i,j in zip(holdingdf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = holdingdf.loc[i,"Date"] + date.timedelta(days=3)
            holdingdf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        holdingdf.loc[i+1,tick]= forw.loc[k,tick]
                        holdingdf.loc[i+1,"date_num"]=4    

holdingdf.sort_index(inplace=True)
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1),inplace=True, drop=True)

for i in holdingdf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        holdingdf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   holdingdf[j]=holdingdf[i]-holdingdf[i].shift(holdingperiod*2-1)
   holdingdf[k]=holdingdf[j]/holdingdf[i].shift(holdingperiod*2-1)*100
   #monthly3df[k+"rsquared"] =monthly3df[k]*monthly3df[k]
   
holdingdf = holdingdf[holdingdf['date_num']== 4]
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1), inplace=True, drop=True)
monthly=pd.DataFrame()
holdingdf.drop(np.arange(1,returnperiod+holdingperiod,1),inplace=True)
holdingdf.reset_index(inplace=True)
del holdingdf["index"]

# %%
#Calculating Backtest returns of winner portfolio
#"winner_test_return" dataframe provides backtested returns 
# for each stock in each of the winner portfolios, for the period of time input in "holdingperiod" return variable
winner_test_return= pd.DataFrame()

for ln in winner_column_list:
    for w,j in zip(winner_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        winner_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

winner_test_return.reset_index(inplace=True)
del winner_test_return["index"]
   
winner_weighted_return= pd.DataFrame()

for ln in winner_column_list:
    winner_weighted_return[ln]= winner_test_return[ln]*winner_weightage[ln]

winner_weighted_return.dropna(inplace=True)

#"winner_weighted_return["Sum"]" dataframe provides total weighted average return for each winner portfolio
winner_weighted_return["Sum"]= winner_weighted_return.loc[:,winner_column_list].sum(axis=1)

# %%
#Calculating Backtest returns of loser portfolio
#"loser_test_return" dataframe provides backtested returns 
# for each stock in each of the loser portfolios, for the period of time input in "holdingperiod" return variable

loser_test_return= pd.DataFrame()

for ln in loser_column_list:
    for w,j in zip(loser_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        loser_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

loser_test_return.reset_index(inplace=True)
del loser_test_return["index"]

loser_weighted_return= pd.DataFrame()

#"loser_weighted_return["Sum"]" dataframe provides total weighted average return for each loser portfolio
loser_weighted_return["Sum"]= loser_test_return.mean(axis=1)

# %%
#Output gives the total return of winner portfolio for each churning period
winner_weighted_return["Sum"]

# %%
#Output gives the total return of loser for each churning period
loser_weighted_return["Sum"]

# %%
avg=winner_weighted_return["Sum"].mean()
std=winner_weighted_return["Sum"].std()
print("Winner Portfolio mean return:",avg)
print("Winner Portfolio Std. dev.:", std)

# %%
avg=loser_weighted_return["Sum"].mean()
std=loser_weighted_return["Sum"].std()
print("Loser Portfolio mean return:",avg)
print("Loser Portfolio Std. dev.:", std)

# %%
sn.set_theme()
plt.title('Winner Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-50,100,step=5))
plt.xticks(np.arange(0,100,step=1))
plt.scatter(winner_weighted_return.index, winner_weighted_return["Sum"])
plt.show()

# %%
sn.set_theme()
plt.title('Loser Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-50,100,step=5))
plt.xticks(np.arange(0,100,step=1))
plt.scatter(loser_weighted_return.index, loser_weighted_return["Sum"])
plt.show()
