# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
import math
import requests
import datetime
import ta
import numpy as np
import yfinance as yf
from datetime import datetime as dt
import seaborn as sn
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, CrosshairTool, HoverTool, NumeralTickFormatter
from bokeh.plotting import figure
from bokeh.layouts import column, row
from bokeh.transform import cumsum

# %%
# download csv from url
url = 'https://archives.nseindia.com/content/indices/ind_nifty100list.csv'
nifty100 = pd.read_csv(url)
nifty100.to_csv('ind_nifty100list.csv', index=False)

# %%
symbol= pd.read_csv("ind_nifty100list.csv")
symbol["ticker"] = symbol["Symbol"] + ".NS"
ticker= symbol['ticker'].values.tolist()
pricechg = symbol["Symbol"] + " pricechg"
percentchg = symbol["Symbol"] #+ " percentchg"
pricechg= pricechg.values.tolist()
percentchg= percentchg.values.tolist()
sd = yf.download(ticker, interval='1d')
data= sd['Adj Close']
# Out:
# [*********************100%***********************]  100 of 100 completed

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13692\4166825869.py in <module>
# ----> 1 for key in data_dict:
#       2     data_dict[key] = data_dict[key].rename(columns={"c": key})
#       3     data_to_concat.append(data_dict[key])
#       4
#       5 price_data = pd.concat(data_to_concat, axis=1, join='inner')
#
# NameError: name 'data_dict' is not defined

# %%
log_ret = np.log(/price_data.shift(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13692\1099475362.py in <module>
# ----> 1 log_ret = np.log(price_data/price_data.shift(1))
#
# NameError: name 'price_data' is not defined
