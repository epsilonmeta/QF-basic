# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import yfinance as yf
import random
import os
import matplotlib.pyplot as plt
from datetime import datetime as dt
import datetime as date
plt.rcParams["figure.figsize"] = (20,10)
import seaborn as sn
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import datetime

# %%
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier

# %%
cwd = os.getcwd() + "\\ind_nifty100list.csv"
symbol= pd.read_csv("Nifty100.csv")
symbol["ticker"] = symbol["Symbol"] + ".NS"
ticker= symbol['ticker'].values.tolist()
sd = yf.download(ticker, interval='1d')
sd.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  100 of 100 completed
#
# 2 Failed downloads:
# - LTI.NS: No timezone found, symbol may be delisted
# - CADILAHC.NS: No timezone found, symbol may be delisted

# %%
symbol["NS"]= ".NS"
symbol["ticker"] = symbol["Symbol"] + symbol["NS"]
symbol
# Out:
#                                          Company Name  \
# 0                                            ACC Ltd.
# 1                              Adani Enterprises Ltd.
# 2                             Adani Green Energy Ltd.
# 3          Adani Ports and Special Economic Zone Ltd.
# 4                             Adani Transmission Ltd.
# 5                                 Ambuja Cements Ltd.
# 6                    Apollo Hospitals Enterprise Ltd.
# 7                                   Asian Paints Ltd.
# 8                               Aurobindo Pharma Ltd.
# 9                              Avenue Supermarts Ltd.
# 10                                     Axis Bank Ltd.
# 11                                    Bajaj Auto Ltd.
# 12                                 Bajaj Finance Ltd.
# 13                                 Bajaj Finserv Ltd.
# 14                   Bajaj Holdings & Investment Ltd.
# 15                                  Bandhan Bank Ltd.
# 16                                     Bank of Baroda
# 17                           Berger Paints India Ltd.
# 18                  Bharat Petroleum Corporation Ltd.
# 19                                 Bharti Airtel Ltd.
# 20                                        Biocon Ltd.
# 21                                         Bosch Ltd.
# 22                          Britannia Industries Ltd.
# 23                             Cadila Healthcare Ltd.
# 24  Cholamandalam Investment and Finance Company Ltd.
# 25                                         Cipla Ltd.
# 26                                    Coal India Ltd.
# 27                     Colgate Palmolive (India) Ltd.
# 28                                           DLF Ltd.
# 29                                   Dabur India Ltd.
# 30                           Divi's Laboratories Ltd.
# 31                      Dr. Reddy's Laboratories Ltd.
# 32                                 Eicher Motors Ltd.
# 33                                  GAIL (India) Ltd.
# 34                                  Gland Pharma Ltd.
# 35                      Godrej Consumer Products Ltd.
# 36                             Grasim Industries Ltd.
# 37                              HCL Technologies Ltd.
# 38                 HDFC Asset Management Company Ltd.
# 39                                     HDFC Bank Ltd.
# 40                   HDFC Life Insurance Company Ltd.
# 41                                 Havells India Ltd.
# 42                                 Hero MotoCorp Ltd.
# 43                           Hindalco Industries Ltd.
# 44               Hindustan Petroleum Corporation Ltd.
# 45                            Hindustan Unilever Ltd.
# 46       Housing Development Finance Corporation Ltd.
# 47                                    ICICI Bank Ltd.
# 48       ICICI Lombard General Insurance Company Ltd.
# 49       ICICI Prudential Life Insurance Company Ltd.
# 50                                           ITC Ltd.
# 51                        Indian Oil Corporation Ltd.
# 52                              Indraprastha Gas Ltd.
# 53                                  Indus Towers Ltd.
# 54                                 IndusInd Bank Ltd.
# 55                             Info Edge (India) Ltd.
# 56                                       Infosys Ltd.
# 57                           InterGlobe Aviation Ltd.
# 58                                     JSW Steel Ltd.
# 59                          Jindal Steel & Power Ltd.
# 60                            Jubilant Foodworks Ltd.
# 61                           Kotak Mahindra Bank Ltd.
# 62                      Larsen & Toubro Infotech Ltd.
# 63                               Larsen & Toubro Ltd.
# 64                                         Lupin Ltd.
# 65                           Mahindra & Mahindra Ltd.
# 66                                        Marico Ltd.
# 67                           Maruti Suzuki India Ltd.
# 68                               Muthoot Finance Ltd.
# 69                                          NMDC Ltd.
# 70                                          NTPC Ltd.
# 71                                  Nestle India Ltd.
# 72                 Oil & Natural Gas Corporation Ltd.
# 73                                 PI Industries Ltd.
# 74                           Pidilite Industries Ltd.
# 75                           Piramal Enterprises Ltd.
# 76               Power Grid Corporation of India Ltd.
# 77        Procter & Gamble Hygiene & Health Care Ltd.
# 78                               Punjab National Bank
# 79                           Reliance Industries Ltd.
# 80                SBI Cards and Payment Services Ltd.
# 81                    SBI Life Insurance Company Ltd.
# 82                                  Shree Cement Ltd.
# 83                                       Siemens Ltd.
# 84                                State Bank of India
# 85                      Steel Authority of India Ltd.
# 86                 Sun Pharmaceutical Industries Ltd.
# 87                     Tata Consultancy Services Ltd.
# 88                        Tata Consumer Products Ltd.
# 89                                   Tata Motors Ltd.
# 90                                    Tata Steel Ltd.
# 91                                 Tech Mahindra Ltd.
# 92                                 Titan Company Ltd.
# 93                       Torrent Pharmaceuticals Ltd.
# 94                                           UPL Ltd.
# 95                              UltraTech Cement Ltd.
# 96                                United Spirits Ltd.
# 97                                       Vedanta Ltd.
# 98                                         Wipro Ltd.
# 99                                      Yes Bank Ltd.
#
#                     Industry      Symbol Series     ISIN Code         ticker  \
# 0   CEMENT & CEMENT PRODUCTS         ACC     EQ  INE012A01025         ACC.NS
# 1                     METALS    ADANIENT     EQ  INE423A01024    ADANIENT.NS
# 2                      POWER  ADANIGREEN     EQ  INE364U01010  ADANIGREEN.NS
# 3                   SERVICES  ADANIPORTS     EQ  INE742F01042  ADANIPORTS.NS
# 4                      POWER  ADANITRANS     EQ  INE931S01010  ADANITRANS.NS
# 5   CEMENT & CEMENT PRODUCTS   AMBUJACEM     EQ  INE079A01024   AMBUJACEM.NS
# 6        HEALTHCARE SERVICES  APOLLOHOSP     EQ  INE437A01024  APOLLOHOSP.NS
# 7             CONSUMER GOODS  ASIANPAINT     EQ  INE021A01026  ASIANPAINT.NS
# 8                     PHARMA  AUROPHARMA     EQ  INE406A01037  AUROPHARMA.NS
# 9          CONSUMER SERVICES       DMART     EQ  INE192R01011       DMART.NS
# 10        FINANCIAL SERVICES    AXISBANK     EQ  INE238A01034    AXISBANK.NS
# 11                AUTOMOBILE  BAJAJ-AUTO     EQ  INE917I01010  BAJAJ-AUTO.NS
# 12        FINANCIAL SERVICES  BAJFINANCE     EQ  INE296A01024  BAJFINANCE.NS
# 13        FINANCIAL SERVICES  BAJAJFINSV     EQ  INE918I01018  BAJAJFINSV.NS
# 14        FINANCIAL SERVICES  BAJAJHLDNG     EQ  INE118A01012  BAJAJHLDNG.NS
# 15        FINANCIAL SERVICES  BANDHANBNK     EQ  INE545U01014  BANDHANBNK.NS
# 16        FINANCIAL SERVICES  BANKBARODA     EQ  INE028A01039  BANKBARODA.NS
# 17            CONSUMER GOODS  BERGEPAINT     EQ  INE463A01038  BERGEPAINT.NS
# 18                 OIL & GAS        BPCL     EQ  INE029A01011        BPCL.NS
# 19                   TELECOM  BHARTIARTL     EQ  INE397D01024  BHARTIARTL.NS
# 20                    PHARMA      BIOCON     EQ  INE376G01013      BIOCON.NS
# 21                AUTOMOBILE    BOSCHLTD     EQ  INE323A01026    BOSCHLTD.NS
# 22            CONSUMER GOODS   BRITANNIA     EQ  INE216A01030   BRITANNIA.NS
# 23                    PHARMA    CADILAHC     EQ  INE010B01027    CADILAHC.NS
# 24        FINANCIAL SERVICES    CHOLAFIN     EQ  INE121A01024    CHOLAFIN.NS
# 25                    PHARMA       CIPLA     EQ  INE059A01026       CIPLA.NS
# 26                    METALS   COALINDIA     EQ  INE522F01014   COALINDIA.NS
# 27            CONSUMER GOODS      COLPAL     EQ  INE259A01022      COLPAL.NS
# 28              CONSTRUCTION         DLF     EQ  INE271C01023         DLF.NS
# 29            CONSUMER GOODS       DABUR     EQ  INE016A01026       DABUR.NS
# 30                    PHARMA    DIVISLAB     EQ  INE361B01024    DIVISLAB.NS
# 31                    PHARMA     DRREDDY     EQ  INE089A01023     DRREDDY.NS
# 32                AUTOMOBILE   EICHERMOT     EQ  INE066A01021   EICHERMOT.NS
# 33                 OIL & GAS        GAIL     EQ  INE129A01019        GAIL.NS
# 34                    PHARMA       GLAND     EQ  INE068V01023       GLAND.NS
# 35            CONSUMER GOODS    GODREJCP     EQ  INE102D01028    GODREJCP.NS
# 36  CEMENT & CEMENT PRODUCTS      GRASIM     EQ  INE047A01021      GRASIM.NS
# 37                        IT     HCLTECH     EQ  INE860A01027     HCLTECH.NS
# 38        FINANCIAL SERVICES     HDFCAMC     EQ  INE127D01025     HDFCAMC.NS
# 39        FINANCIAL SERVICES    HDFCBANK     EQ  INE040A01034    HDFCBANK.NS
# 40        FINANCIAL SERVICES    HDFCLIFE     EQ  INE795G01014    HDFCLIFE.NS
# 41            CONSUMER GOODS     HAVELLS     EQ  INE176B01034     HAVELLS.NS
# 42                AUTOMOBILE  HEROMOTOCO     EQ  INE158A01026  HEROMOTOCO.NS
# 43                    METALS    HINDALCO     EQ  INE038A01020    HINDALCO.NS
# 44                 OIL & GAS   HINDPETRO     EQ  INE094A01015   HINDPETRO.NS
# 45            CONSUMER GOODS  HINDUNILVR     EQ  INE030A01027  HINDUNILVR.NS
# 46        FINANCIAL SERVICES        HDFC     EQ  INE001A01036        HDFC.NS
# 47        FINANCIAL SERVICES   ICICIBANK     EQ  INE090A01021   ICICIBANK.NS
# 48        FINANCIAL SERVICES     ICICIGI     EQ  INE765G01017     ICICIGI.NS
# 49        FINANCIAL SERVICES  ICICIPRULI     EQ  INE726G01019  ICICIPRULI.NS
# 50            CONSUMER GOODS         ITC     EQ  INE154A01025         ITC.NS
# 51                 OIL & GAS         IOC     EQ  INE242A01010         IOC.NS
# 52                 OIL & GAS         IGL     EQ  INE203G01027         IGL.NS
# 53                   TELECOM  INDUSTOWER     EQ  INE121J01017  INDUSTOWER.NS
# 54        FINANCIAL SERVICES  INDUSINDBK     EQ  INE095A01012  INDUSINDBK.NS
# 55         CONSUMER SERVICES      NAUKRI     EQ  INE663F01024      NAUKRI.NS
# 56                        IT        INFY     EQ  INE009A01021        INFY.NS
# 57                  SERVICES      INDIGO     EQ  INE646L01027      INDIGO.NS
# 58                    METALS    JSWSTEEL     EQ  INE019A01038    JSWSTEEL.NS
# 59                    METALS  JINDALSTEL     EQ  INE749A01030  JINDALSTEL.NS
# 60         CONSUMER SERVICES    JUBLFOOD     EQ  INE797F01012    JUBLFOOD.NS
# 61        FINANCIAL SERVICES   KOTAKBANK     EQ  INE237A01028   KOTAKBANK.NS
# 62                        IT         LTI     EQ  INE214T01019         LTI.NS
# 63              CONSTRUCTION          LT     EQ  INE018A01030          LT.NS
# 64                    PHARMA       LUPIN     EQ  INE326A01037       LUPIN.NS
# 65                AUTOMOBILE         M&M     EQ  INE101A01026         M&M.NS
# 66            CONSUMER GOODS      MARICO     EQ  INE196A01026      MARICO.NS
# 67                AUTOMOBILE      MARUTI     EQ  INE585B01010      MARUTI.NS
# 68        FINANCIAL SERVICES  MUTHOOTFIN     EQ  INE414G01012  MUTHOOTFIN.NS
# 69                    METALS        NMDC     EQ  INE584A01023        NMDC.NS
# 70                     POWER        NTPC     EQ  INE733E01010        NTPC.NS
# 71            CONSUMER GOODS   NESTLEIND     EQ  INE239A01016   NESTLEIND.NS
# 72                 OIL & GAS        ONGC     EQ  INE213A01029        ONGC.NS
# 73  FERTILISERS & PESTICIDES       PIIND     EQ  INE603J01030       PIIND.NS
# 74                 CHEMICALS  PIDILITIND     EQ  INE318A01026  PIDILITIND.NS
# 75        FINANCIAL SERVICES         PEL     EQ  INE140A01024         PEL.NS
# 76                     POWER   POWERGRID     EQ  INE752E01010   POWERGRID.NS
# 77            CONSUMER GOODS        PGHH     EQ  INE179A01014        PGHH.NS
# 78        FINANCIAL SERVICES         PNB     EQ  INE160A01022         PNB.NS
# 79                 OIL & GAS    RELIANCE     EQ  INE002A01018    RELIANCE.NS
# 80        FINANCIAL SERVICES     SBICARD     EQ  INE018E01016     SBICARD.NS
# 81        FINANCIAL SERVICES     SBILIFE     EQ  INE123W01016     SBILIFE.NS
# 82  CEMENT & CEMENT PRODUCTS    SHREECEM     EQ  INE070A01015    SHREECEM.NS
# 83  INDUSTRIAL MANUFACTURING     SIEMENS     EQ  INE003A01024     SIEMENS.NS
# 84        FINANCIAL SERVICES        SBIN     EQ  INE062A01020        SBIN.NS
# 85                    METALS        SAIL     EQ  INE114A01011        SAIL.NS
# 86                    PHARMA   SUNPHARMA     EQ  INE044A01036   SUNPHARMA.NS
# 87                        IT         TCS     EQ  INE467B01029         TCS.NS
# 88            CONSUMER GOODS  TATACONSUM     EQ  INE192A01025  TATACONSUM.NS
# 89                AUTOMOBILE  TATAMOTORS     EQ  INE155A01022  TATAMOTORS.NS
# 90                    METALS   TATASTEEL     EQ  INE081A01012   TATASTEEL.NS
# 91                        IT       TECHM     EQ  INE669C01036       TECHM.NS
# 92            CONSUMER GOODS       TITAN     EQ  INE280A01028       TITAN.NS
# 93                    PHARMA  TORNTPHARM     EQ  INE685A01028  TORNTPHARM.NS
# 94  FERTILISERS & PESTICIDES         UPL     EQ  INE628A01036         UPL.NS
# 95  CEMENT & CEMENT PRODUCTS  ULTRACEMCO     EQ  INE481G01011  ULTRACEMCO.NS
# 96            CONSUMER GOODS  MCDOWELL-N     EQ  INE854D01024  MCDOWELL-N.NS
# 97                    METALS        VEDL     EQ  INE205A01025        VEDL.NS
# 98                        IT       WIPRO     EQ  INE075A01022       WIPRO.NS
# 99        FINANCIAL SERVICES     YESBANK     EQ  INE528G01035     YESBANK.NS
#
#      NS
# 0   .NS
# 1   .NS
# 2   .NS
# 3   .NS
# 4   .NS
# 5   .NS
# 6   .NS
# 7   .NS
# 8   .NS
# 9   .NS
# 10  .NS
# 11  .NS
# 12  .NS
# 13  .NS
# 14  .NS
# 15  .NS
# 16  .NS
# 17  .NS
# 18  .NS
# 19  .NS
# 20  .NS
# 21  .NS
# 22  .NS
# 23  .NS
# 24  .NS
# 25  .NS
# 26  .NS
# 27  .NS
# 28  .NS
# 29  .NS
# 30  .NS
# 31  .NS
# 32  .NS
# 33  .NS
# 34  .NS
# 35  .NS
# 36  .NS
# 37  .NS
# 38  .NS
# 39  .NS
# 40  .NS
# 41  .NS
# 42  .NS
# 43  .NS
# 44  .NS
# 45  .NS
# 46  .NS
# 47  .NS
# 48  .NS
# 49  .NS
# 50  .NS
# 51  .NS
# 52  .NS
# 53  .NS
# 54  .NS
# 55  .NS
# 56  .NS
# 57  .NS
# 58  .NS
# 59  .NS
# 60  .NS
# 61  .NS
# 62  .NS
# 63  .NS
# 64  .NS
# 65  .NS
# 66  .NS
# 67  .NS
# 68  .NS
# 69  .NS
# 70  .NS
# 71  .NS
# 72  .NS
# 73  .NS
# 74  .NS
# 75  .NS
# 76  .NS
# 77  .NS
# 78  .NS
# 79  .NS
# 80  .NS
# 81  .NS
# 82  .NS
# 83  .NS
# 84  .NS
# 85  .NS
# 86  .NS
# 87  .NS
# 88  .NS
# 89  .NS
# 90  .NS
# 91  .NS
# 92  .NS
# 93  .NS
# 94  .NS
# 95  .NS
# 96  .NS
# 97  .NS
# 98  .NS
# 99  .NS

# %%
pricechg = symbol["Symbol"] + " pricechg"
percentchg = symbol["Symbol"] #+ " percentchg"
ticker = symbol['ticker']
pricechg= pricechg.values.tolist()
percentchg= percentchg.values.tolist()
ticker= ticker.values.tolist()

# %%
sd = yf.download(ticker, interval='1d')

data= sd['Adj Close']
# Out:
# [*********************100%***********************]  100 of 100 completed
#
# 2 Failed downloads:
# - LTI.NS: No timezone found, symbol may be delisted
# - CADILAHC.NS: No timezone found, symbol may be delisted

# %%
# This coding block requires inputs for each of the variables as described below-
# returnperiod- No. of months over which the returns of stocks is measured to create a portfolio
# holdingperiod- Following no. of months over which the stocks in the portfolio will be held for
# sdate_input- Starting date from where the data for each stock should start (Starting date must fall on a Monday)
# fdate_input- Ending date for where the data for each stock should end (Ending date must fall on a Friday)
# input for dates should be in the following format -> "YYYY-MM-DD"
returnperiod= 3
holdingperiod= 1
# totalmonth = returnperiod +holdingperiod
# total_days = (totalmonth+1) *30
# get last 3 months and year
last3rd_month = datetime.date.today().replace(day=1) - datetime.timedelta(days=127)
sdate_input= last3rd_month.replace(day=1)
sdate_input = sdate_input + datetime.timedelta(days=-sdate_input.weekday(), weeks=1)

fdate_input= datetime.date.today().replace(day=1) - datetime.timedelta(days=33)
fdate_input = fdate_input + datetime.timedelta(days=4-fdate_input.weekday(), weeks=0)

sdate_input = sdate_input.strftime("%Y-%m-%d")
fdate_input = fdate_input.strftime("%Y-%m-%d")
print(sdate_input, fdate_input)
# Out:
# 2022-11-07 2023-03-03

# %%
start= dt.strptime(sdate_input, '%Y-%m-%d')
finish= dt.strptime(fdate_input,'%Y-%m-%d')

forw = data.loc[start:finish]
dailydf = data.loc[start:finish]
forw.reset_index(inplace=True)
forw['date_num'] = forw['Date'].dt.weekday
weeklydf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
weeklydfcopy = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
returndf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]

# %%
weeklydfcopy.set_index(np.arange(len(weeklydfcopy.index)), inplace=True, drop=True)

# %%
#Calculating return of stocks depending on the number of months input in "returnperiod" variable
#for creating porfolios 
for i,j in zip(returndf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = returndf.loc[i,"Date"] + datetime.timedelta(days=3)
            returndf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        returndf.loc[i+1,tick]= forw.loc[k,tick]
                        returndf.loc[i+1,"date_num"]=4
    
returndf.sort_index(inplace=True)
returndf.set_index(np.arange(1,len(returndf.index)+1,1),inplace=True, drop=True)

for i in returndf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        returndf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   returndf[j]=returndf[i]-returndf[i].shift(returnperiod*2-1)
   returndf[k]=returndf[j]/returndf[i].shift(returnperiod*2-1)*100
   
returndf = returndf[returndf["date_num"]==4]
returndf.set_index(np.arange(1,len(returndf.index)+1,1), inplace=True, drop=True)

# %%
returndf.tail()
# Out:
#         Date       ACC.NS  ADANIENT.NS  ADANIGREEN.NS  ADANIPORTS.NS  \
# 1 2022-12-02  2609.300049  3922.500000    2062.300049     888.200012
# 2 2022-12-30  2441.600098  3858.350098    1931.800049     818.099976
# 3 2023-01-27  1879.750000  2761.449951    1486.250000     596.950012
# 4 2023-02-24  1730.000000  1315.650024     486.500000     558.900024
#
#    ADANITRANS.NS  AMBUJACEM.NS  APOLLOHOSP.NS  ASIANPAINT.NS  AUROPHARMA.NS  \
# 1    2745.699951    577.950012    4864.878906    3143.449951     467.061890
# 2    2589.250000    524.099976    4471.560059    3087.899902     435.560059
# 3    2014.199951    380.450012    4238.424805    2722.649902     413.747284
# 4     712.299988    345.250000    4470.649902    2738.500000     469.250000
#
#    AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJAJHLDNG.NS  BAJFINANCE.NS  \
# 1   905.150024    3659.350098    1642.650024    6374.450195    6675.750000
# 2   933.750000    3616.050049    1547.849976    5741.600098    6575.200195
# 3   873.750000    3936.750000    1314.199951    5905.000000    5760.700195
# 4   851.400024    3849.949951    1359.000000    6103.299805    6236.250000
#
#    BANDHANBNK.NS  BANKBARODA.NS  BERGEPAINT.NS  BHARTIARTL.NS   BIOCON.NS  \
# 1     240.100006     171.199997     616.400024     848.650024  283.549988
# 2     234.199997     185.699997     581.349976     806.099976  261.850006
# 3     240.199997     157.250000     539.500000     774.500000  235.500000
# 4     228.800003     154.600006     558.049988     757.099976  226.300003
#
#     BOSCHLTD.NS     BPCL.NS  BRITANNIA.NS  CADILAHC.NS  CHOLAFIN.NS  \
# 1  16957.730469  341.100006   4432.899902          NaN   730.455261
# 2  17077.320312  330.500000   4307.450195          NaN   721.719543
# 3  16515.369141  336.549988   4380.399902          NaN   708.740784
# 4  17810.300781  317.549988   4442.549805          NaN   762.849976
#
#       CIPLA.NS  COALINDIA.NS    COLPAL.NS    DABUR.NS  DIVISLAB.NS  \
# 1  1114.349976    221.185120  1617.900024  591.150024  3381.250000
# 2  1075.949951    219.672165  1536.300049  561.450012  3413.199951
# 3  1047.250000    217.085480  1446.900024  562.049988  3387.449951
# 4   961.799988    217.050003  1464.550049  534.900024  2915.199951
#
#        DLF.NS     DMART.NS   DRREDDY.NS  EICHERMOT.NS    GAIL.NS     GLAND.NS  \
# 1  410.750000  4005.750000  4510.399902   3331.850098  89.804733  1720.750000
# 2  375.000000  4068.750000  4237.549805   3227.750000  92.550911  1576.550049
# 3  355.950012  3562.350098  4314.000000   3169.750000  95.537979  1356.500000
# 4  346.049988  3499.199951  4491.100098   3205.600098  99.681328  1288.300049
#
#    GODREJCP.NS    GRASIM.NS   HAVELLS.NS   HCLTECH.NS      HDFC.NS  \
# 1   881.650024  1819.650024  1235.835449  1125.367065  2665.300049
# 2   874.049988  1723.500000  1097.184814  1029.980225  2637.600098
# 3   907.099976  1578.449951  1171.199951  1115.599976  2661.500000
# 4   927.799988  1575.199951  1180.900024  1094.849976  2577.149902
#
#     HDFCAMC.NS  HDFCBANK.NS  HDFCLIFE.NS  HEROMOTOCO.NS  HINDALCO.NS  \
# 1  2193.949951  1607.099976   589.849976    2748.744385   461.100006
# 2  2181.500000  1628.150024   566.250000    2669.219238   473.350006
# 3  1915.500000  1615.800049   587.700012    2666.587646   479.000000
# 4  1815.250000  1588.949951   482.850006    2485.649902   415.250000
#
#    HINDPETRO.NS  HINDUNILVR.NS  ICICIBANK.NS   ICICIGI.NS  ICICIPRULI.NS  \
# 1    235.699997    2615.100098    930.599976  1238.650024     482.250000
# 2    235.149994    2561.050049    890.849976  1236.800049     451.299988
# 3    234.300003    2612.149902    817.200012  1131.699951     465.250000
# 4    217.000000    2484.199951    839.700012  1089.099976     399.700012
#
#        IGL.NS    INDIGO.NS  INDUSINDBK.NS  INDUSTOWER.NS      INFY.NS  \
# 1  425.398438  1916.500000    1178.699951     202.750000  1637.900024
# 2  401.627716  2007.699951    1220.099976     190.449997  1508.199951
# 3  405.460144  2094.050049    1116.400024     137.000000  1519.150024
# 4  428.239746  1853.250000    1079.150024     171.199997  1550.650024
#
#       IOC.NS      ITC.NS  JINDALSTEL.NS  JSWSTEEL.NS  JUBLFOOD.NS  \
# 1  77.000000  331.915436     564.450012   743.049988   547.650024
# 2  76.500000  326.402374     580.599976   768.049988   511.049988
# 3  81.000000  340.628021     588.150024   721.349976   484.299988
# 4  77.349998  385.100006     560.299988   685.000000   442.149994
#
#    KOTAKBANK.NS        LT.NS  LTI.NS    LUPIN.NS       M&M.NS   MARICO.NS  \
# 1   1930.800049  2085.500000     NaN  776.000000  1264.599976  499.323944
# 2   1827.250000  2085.800049     NaN  733.700012  1249.199951  505.270050
# 3   1713.099976  2159.850098     NaN  742.099976  1320.199951  499.274384
# 4   1697.300049  2134.050049     NaN  659.349976  1280.199951  494.319275
#
#      MARUTI.NS  MCDOWELL-N.NS  MUTHOOTFIN.NS    NAUKRI.NS  NESTLEIND.NS  \
# 1  8815.849609     935.900024    1135.750000  4042.600098  19751.199219
# 2  8394.599609     877.549988    1063.050049  3932.050049  19606.000000
# 3  8737.500000     767.150024    1010.150024  3643.850098  19216.349609
# 4  8660.500000     743.400024     965.400024  3555.699951  18680.900391
#
#       NMDC.NS     NTPC.NS     ONGC.NS      PEL.NS       PGHH.NS  \
# 1  116.058693  167.766312  137.255646  859.700012  14057.898438
# 2  119.107773  162.211456  142.954330  828.400024  14450.732422
# 3  119.010971  162.065277  143.831055  809.799988  13485.474609
# 4  112.000000  171.000000  155.000000  794.150024  13720.099609
#
#    PIDILITIND.NS     PIIND.NS     PNB.NS  POWERGRID.NS  RELIANCE.NS  \
# 1    2736.199951  3480.637695  54.000000    214.731979  2722.149902
# 2    2550.149902  3415.031006  56.450001    208.772629  2547.199951
# 3    2290.649902  2953.738770  50.799999    214.194672  2337.350098
# 4    2275.699951  3114.750000  47.549999    215.050003  2383.699951
#
#      SAIL.NS  SBICARD.NS   SBILIFE.NS     SBIN.NS   SHREECEM.NS   SIEMENS.NS  \
# 1  85.739517  835.402649  1292.115601  607.549988  24051.287109  2747.943604
# 2  81.687271  792.703308  1228.415283  613.700012  23247.343750  2807.187988
# 3  87.123207  696.891296  1247.320801  539.950012  21861.603516  2937.794189
# 4  81.983772  743.726074  1119.421265  521.049988  25412.800781  3246.500000
#
#    SUNPHARMA.NS  TATACONSUM.NS  TATAMOTORS.NS  TATASTEEL.NS       TCS.NS  \
# 1   1032.249634     795.549988     435.399994    112.000000  3370.867432
# 2    993.937256     766.950012     387.950012    112.650002  3192.039795
# 3   1035.624268     735.250000     445.600006    120.650002  3411.050049
# 4    970.500000     716.150024     427.750000    109.750000  3400.449951
#
#       TECHM.NS     TITAN.NS  TORNTPHARM.NS  ULTRACEMCO.NS      UPL.NS  \
# 1  1114.750000  2617.899902    1606.372803    7237.049805  783.700012
# 2  1016.400024  2597.500000    1536.513184    6959.049805  716.150024
# 3  1030.099976  2331.250000    1523.433228    6715.600098  744.700012
# 4  1119.000000  2399.100098    1480.449951    7216.700195  738.299988
#
#       VEDL.NS    WIPRO.NS  YESBANK.NS  date_num  ACC pricechg        ACC  \
# 1  301.854523  411.386719       17.40         4           NaN        NaN
# 2  296.612793  391.785004       20.60         4           NaN        NaN
# 3  307.528992  398.049988       17.50         4   -605.199951 -24.354613
# 4  294.450012  393.299988       16.15         4   -891.100098 -33.997179
#
#    ADANIENT pricechg   ADANIENT  ADANIGREEN pricechg  ADANIGREEN  \
# 1                NaN        NaN                  NaN         NaN
# 2                NaN        NaN                  NaN         NaN
# 3       -1199.150146 -30.276981          -679.449951  -31.373227
# 4       -2614.749878 -66.526306         -1555.599976  -76.176485
#
#    ADANIPORTS pricechg  ADANIPORTS  ADANITRANS pricechg  ADANITRANS  \
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3          -256.049988  -30.017584         -1318.250000  -39.557983
# 4          -334.250000  -37.423724         -2003.849915  -73.775380
#
#    AMBUJACEM pricechg  AMBUJACEM  APOLLOHOSP pricechg  APOLLOHOSP  \
# 1                 NaN        NaN                  NaN         NaN
# 2                 NaN        NaN                  NaN         NaN
# 3         -187.649963 -33.031151          -119.488770   -2.741880
# 4         -228.099976 -39.783725          -301.254395   -6.313085
#
#    ASIANPAINT pricechg  ASIANPAINT  AUROPHARMA pricechg  AUROPHARMA  \
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3          -380.900146  -12.273047          -140.068878  -25.291584
# 4          -418.399902  -13.253506             6.312164    1.363501
#
#    DMART pricechg      DMART  AXISBANK pricechg  AXISBANK  \
# 1             NaN        NaN                NaN       NaN
# 2             NaN        NaN                NaN       NaN
# 3     -611.149902 -14.643582           0.799988  0.091642
# 4     -528.949951 -13.131337         -47.799988 -5.315835
#
#    BAJAJ-AUTO pricechg  BAJAJ-AUTO  BAJFINANCE pricechg  BAJFINANCE  \
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3           166.899902    4.427229         -1429.349609  -19.879551
# 4           190.050049    5.192766          -424.200195   -6.368942
#
#    BAJAJFINSV pricechg  BAJAJFINSV  BAJAJHLDNG pricechg  BAJAJHLDNG  \
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3          -463.850098  -26.087573          -859.000000  -12.699586
# 4          -275.199951  -16.840042          -153.850098   -2.458789
#
#    BANDHANBNK pricechg  BANDHANBNK  BANKBARODA pricechg  BANKBARODA  \
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3            14.599991    6.471627            -1.100006   -0.694668
# 4           -12.149994   -5.042537           -17.349991  -10.090137
#
#    BERGEPAINT pricechg  BERGEPAINT  BPCL pricechg      BPCL  \
# 1                  NaN         NaN            NaN       NaN
# 2                  NaN         NaN            NaN       NaN
# 3           -74.950012  -12.197902      26.799988  8.652135
# 4           -64.150024  -10.310193     -20.850006 -6.161349
#
#    BHARTIARTL pricechg  BHARTIARTL  BIOCON pricechg     BIOCON  \
# 1                  NaN         NaN              NaN        NaN
# 2                  NaN         NaN              NaN        NaN
# 3           -48.200012   -5.858759       -42.899994 -15.409481
# 4           -87.000000  -10.306836       -53.150009 -19.019505
#
#    BOSCHLTD pricechg  BOSCHLTD  BRITANNIA pricechg  BRITANNIA  \
# 1                NaN       NaN                 NaN        NaN
# 2                NaN       NaN                 NaN        NaN
# 3         247.194336  1.519496          241.149902   5.825932
# 4         797.771484  4.689317           39.199707   0.890225
#
#    CADILAHC pricechg  CADILAHC  CHOLAFIN pricechg  CHOLAFIN  CIPLA pricechg  \
# 1                NaN       NaN                NaN       NaN             NaN
# 2                NaN       NaN                NaN       NaN             NaN
# 3                NaN       NaN         -38.387146 -5.137962      -83.650024
# 4                NaN       NaN          26.354614  3.578382     -153.549988
#
#        CIPLA  COALINDIA pricechg  COALINDIA  COLPAL pricechg    COLPAL  \
# 1        NaN                 NaN        NaN              NaN       NaN
# 2        NaN                 NaN        NaN              NaN       NaN
# 3  -7.396766          -11.720474  -5.122452      -140.949951 -8.876780
# 4 -13.766978           -8.673996  -3.842744      -133.699951 -8.365397
#
#    DLF pricechg        DLF  DABUR pricechg     DABUR  DIVISLAB pricechg  \
# 1           NaN        NaN             NaN       NaN                NaN
# 2           NaN        NaN             NaN       NaN                NaN
# 3    -41.849976 -10.520356        8.450012  1.526375         -27.100098
# 4    -71.200012 -17.064113      -52.199951 -8.891152        -453.650146
#
#     DIVISLAB  DRREDDY pricechg   DRREDDY  EICHERMOT pricechg  EICHERMOT  \
# 1        NaN               NaN       NaN                 NaN        NaN
# 2        NaN               NaN       NaN                 NaN        NaN
# 3  -0.793665       -171.450195 -3.822363         -585.399902 -15.589255
# 4 -13.466024         11.700195  0.261200         -138.799805  -4.150216
#
#    GAIL pricechg       GAIL  GLAND pricechg      GLAND  GODREJCP pricechg  \
# 1            NaN        NaN             NaN        NaN                NaN
# 2            NaN        NaN             NaN        NaN                NaN
# 3       8.286705   9.497517     -448.550049 -24.849729          80.250000
# 4       9.924767  11.057427     -460.250000 -26.321809          45.299988
#
#    GODREJCP  GRASIM pricechg     GRASIM  HCLTECH pricechg   HCLTECH  \
# 1       NaN              NaN        NaN               NaN       NaN
# 2       NaN              NaN        NaN               NaN       NaN
# 3  9.705509      -196.750000 -11.083259         77.840210  7.500793
# 4  5.133143      -240.950073 -13.267080        -25.859253 -2.307401
#
#    HDFCAMC pricechg    HDFCAMC  HDFCBANK pricechg  HDFCBANK  \
# 1               NaN        NaN                NaN       NaN
# 2               NaN        NaN                NaN       NaN
# 3       -173.100098  -8.287853              107.0  7.091728
# 4       -371.550049 -16.990582              -24.0 -1.487957
#
#    HDFCLIFE pricechg   HDFCLIFE  HAVELLS pricechg   HAVELLS  \
# 1                NaN        NaN               NaN       NaN
# 2                NaN        NaN               NaN       NaN
# 3          51.700012   9.645525        -58.151855 -4.730286
# 4        -106.050018 -18.008153        -50.347046 -4.089110
#
#    HEROMOTOCO pricechg  HEROMOTOCO  HINDALCO pricechg   HINDALCO  \
# 1                  NaN         NaN                NaN        NaN
# 2                  NaN         NaN                NaN        NaN
# 3           112.173584    4.391363          41.500000   9.485714
# 4          -270.111572   -9.801704         -65.950012 -13.705322
#
#    HINDPETRO pricechg  HINDPETRO  HINDUNILVR pricechg  HINDUNILVR  \
# 1                 NaN        NaN                  NaN         NaN
# 2                 NaN        NaN                  NaN         NaN
# 3           24.400009  11.624588            79.349854    3.132891
# 4          -13.100006  -5.693179          -135.650146   -5.177783
#
#    HDFC pricechg      HDFC  ICICIBANK pricechg  ICICIBANK  ICICIGI pricechg  \
# 1            NaN       NaN                 NaN        NaN               NaN
# 2            NaN       NaN                 NaN        NaN               NaN
# 3     154.100098  6.145813         -100.299988 -10.931879        -28.550049
# 4     -98.650146 -3.686753          -93.899963 -10.057837       -134.300049
#
#      ICICIGI  ICICIPRULI pricechg  ICICIPRULI  ITC pricechg        ITC  \
# 1        NaN                  NaN         NaN           NaN        NaN
# 2        NaN                  NaN         NaN           NaN        NaN
# 3  -2.460681           -47.849976   -9.325663     -7.383545  -2.121638
# 4 -10.977607           -75.599976  -15.905739     53.578369  16.161349
#
#    IOC pricechg        IOC  IGL pricechg       IGL  INDUSTOWER pricechg  \
# 1           NaN        NaN           NaN       NaN                  NaN
# 2           NaN        NaN           NaN       NaN                  NaN
# 3     10.900002  15.549218     -5.093689 -1.240687           -54.600006
# 4      0.299995   0.389352      5.752014  1.361463           -30.350006
#
#    INDUSTOWER  INDUSINDBK pricechg  INDUSINDBK  NAUKRI pricechg     NAUKRI  \
# 1         NaN                  NaN         NaN              NaN        NaN
# 2         NaN                  NaN         NaN              NaN        NaN
# 3  -28.496871           -27.750000   -2.425381      -288.709961  -7.341527
# 4  -15.058301          -116.349976   -9.732328      -500.750000 -12.344538
#
#    INFY pricechg      INFY  INDIGO pricechg     INDIGO  JSWSTEEL pricechg  \
# 1            NaN       NaN              NaN        NaN                NaN
# 2            NaN       NaN              NaN        NaN                NaN
# 3      11.700073  0.776150       316.000000  17.772278          11.349976
# 4     -89.099976 -5.433754       -65.800049  -3.428782         -71.599976
#
#    JSWSTEEL  JINDALSTEL pricechg  JINDALSTEL  JUBLFOOD pricechg   JUBLFOOD  \
# 1       NaN                  NaN         NaN                NaN        NaN
# 2       NaN                  NaN         NaN                NaN        NaN
# 3  1.598588            94.100037   19.046663        -128.400024 -20.956426
# 4 -9.463386            -9.049988   -1.589530        -111.699982 -20.167913
#
#    KOTAKBANK pricechg  KOTAKBANK  LTI pricechg  LTI  LT pricechg        LT  \
# 1                 NaN        NaN           NaN  NaN          NaN       NaN
# 2                 NaN        NaN           NaN  NaN          NaN       NaN
# 3         -169.500000  -9.003506           NaN  NaN   142.200073  7.047807
# 4         -241.149902 -12.440347           NaN  NaN    48.449951  2.323070
#
#    LUPIN pricechg      LUPIN  M&M pricechg       M&M  MARICO pricechg  \
# 1             NaN        NaN           NaN       NaN              NaN
# 2             NaN        NaN           NaN       NaN              NaN
# 3           32.25   4.543214    -31.100098 -2.301495        -1.090118
# 4         -110.75 -14.381250     20.399902  1.619297        -2.130737
#
#      MARICO  MARUTI pricechg    MARUTI  MUTHOOTFIN pricechg  MUTHOOTFIN  \
# 1       NaN              NaN       NaN                  NaN         NaN
# 2       NaN              NaN       NaN                  NaN         NaN
# 3 -0.217865      -595.799805 -6.383592          -103.099976   -9.261170
# 4 -0.429195      -131.549805 -1.496236          -176.699951  -15.471496
#
#    NMDC pricechg      NMDC  NTPC pricechg      NTPC  NESTLEIND pricechg  \
# 1            NaN       NaN            NaN       NaN                 NaN
# 2            NaN       NaN            NaN       NaN                 NaN
# 3       8.324471  7.520764      -9.306824 -5.430769        -1263.900391
# 4      -6.817383 -5.737698       0.310089  0.181668        -1071.298828
#
#    NESTLEIND  ONGC pricechg       ONGC  PIIND pricechg      PIIND  \
# 1        NaN            NaN        NaN             NaN        NaN
# 2        NaN            NaN        NaN             NaN        NaN
# 3  -6.171313      15.291611  11.896434     -338.717041 -10.287672
# 4  -5.423694      14.968063  10.689035     -361.893311 -10.409273
#
#    PIDILITIND pricechg  PIDILITIND  PEL pricechg        PEL  \
# 1                  NaN         NaN           NaN        NaN
# 2                  NaN         NaN           NaN        NaN
# 3          -338.000000  -12.858312    -95.100037 -10.509452
# 4          -458.100098  -16.756898   -102.099976 -11.391908
#
#    POWERGRID pricechg  POWERGRID  PGHH pricechg      PGHH  PNB pricechg  \
# 1                 NaN        NaN            NaN       NaN           NaN
# 2                 NaN        NaN            NaN       NaN           NaN
# 3           -3.345184  -1.537734    -520.332031 -3.715116      8.950001
# 4           -1.733551  -0.799669    -388.202148 -2.751587     -7.600002
#
#          PNB  RELIANCE pricechg   RELIANCE  SBICARD pricechg    SBICARD  \
# 1        NaN                NaN        NaN               NaN        NaN
# 2        NaN                NaN        NaN               NaN        NaN
# 3  21.385905            -269.25 -10.329548       -106.773315 -13.285805
# 4 -13.780602            -298.75 -11.137207        -84.501892 -10.202733
#
#    SBILIFE pricechg    SBILIFE  SHREECEM pricechg  SHREECEM  SIEMENS pricechg  \
# 1               NaN        NaN                NaN       NaN               NaN
# 2               NaN        NaN                NaN       NaN               NaN
# 3        -28.333496  -2.221095       -1502.179688 -6.429522         22.346924
# 4       -162.119263 -12.650342        1700.150391  7.169803        501.188232
#
#      SIEMENS  SBIN pricechg       SBIN  SAIL pricechg      SAIL  \
# 1        NaN            NaN        NaN            NaN       NaN
# 2        NaN            NaN        NaN            NaN       NaN
# 3   0.766501     -74.200012 -12.081740       1.037773  1.205515
# 4  18.256150     -96.250000 -15.592095      -5.090019 -5.845639
#
#    SUNPHARMA pricechg  SUNPHARMA  TCS pricechg       TCS  TATACONSUM pricechg  \
# 1                 NaN        NaN           NaN       NaN                  NaN
# 2                 NaN        NaN           NaN       NaN                  NaN
# 3           14.937866   1.463512    241.553467  7.621193           -36.900024
# 4          -61.154053  -5.927767     42.569580  1.267752           -84.349976
#
#    TATACONSUM  TATAMOTORS pricechg  TATAMOTORS  TATASTEEL pricechg  TATASTEEL  \
# 1         NaN                  NaN         NaN                 NaN        NaN
# 2         NaN                  NaN         NaN                 NaN        NaN
# 3   -4.778867            10.600006    2.436783           13.950005  13.074044
# 4  -10.537161            -1.000000   -0.233236           -6.099998  -5.265428
#
#    TECHM pricechg     TECHM  TITAN pricechg      TITAN  TORNTPHARM pricechg  \
# 1             NaN       NaN             NaN        NaN                  NaN
# 2             NaN       NaN             NaN        NaN                  NaN
# 3       -5.400024 -0.521490     -410.300049 -14.965988          -142.642212
# 4       19.250000  1.750398     -216.549805  -8.279006          -124.733765
#
#    TORNTPHARM  UPL pricechg       UPL  ULTRACEMCO pricechg  ULTRACEMCO  \
# 1         NaN           NaN       NaN                  NaN         NaN
# 2         NaN           NaN       NaN                  NaN         NaN
# 3   -8.561570         -3.75 -0.501035          -257.899902   -3.698285
# 4   -7.770685        -64.50 -8.034380            18.100098    0.251439
#
#    MCDOWELL-N pricechg  MCDOWELL-N  VEDL pricechg       VEDL  WIPRO pricechg  \
# 1                  NaN         NaN            NaN        NaN             NaN
# 2                  NaN         NaN            NaN        NaN             NaN
# 3          -127.099976  -14.213025      29.309845  10.534805        7.511902
# 4          -186.199951  -20.030116     -12.598114  -4.102977      -18.036865
#
#       WIPRO  YESBANK pricechg   YESBANK
# 1       NaN               NaN       NaN
# 2       NaN               NaN       NaN
# 3  1.923475          0.950001  5.740186
# 4 -4.384938         -1.300001 -7.449863

# %%
#Portfolio formation
winner_portfolio= pd.DataFrame()
loser_portfolio= pd.DataFrame() 

# Portfolio of top 10 stocks made
for i in returndf.index:

    winner_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"]

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W1']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W2']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W3']= j
            returndf.loc[i,j]= None
    
    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W4']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W5']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W6']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W7']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W8']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W9']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W10']= j
            returndf.loc[i,j]= None

# Portfolio of bottom 10 stocks made
for i in returndf.index:

    loser_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"] 

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L1']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L2']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L3']= j
            returndf.loc[i,j]= None
    
    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L4']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L5']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L6']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L7']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L8']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L9']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L10']= j
            returndf.loc[i,j]= None


winner_portfolio.dropna(inplace=True)
winner_portfolio.reset_index(inplace=True)
del winner_portfolio["index"]

winner_weightage = pd.DataFrame()

winner_column_list=winner_portfolio.columns.values.tolist()
del winner_column_list[0]

loser_portfolio.dropna(inplace=True)
loser_portfolio.reset_index(inplace=True)
del loser_portfolio["index"]

loser_weightage = pd.DataFrame()

loser_column_list=loser_portfolio.columns.values.tolist()
del loser_column_list[0]

# %%
#Calculating weightage for winner portfolio using mean variance optimization
#To check the weightage dataframe print "winner_weightage" variable

for num in winner_portfolio.index:
    for d in dailydf.index:
        df = pd.DataFrame()
        if winner_portfolio.loc[num,"Date"] == d:
            list=winner_portfolio.loc[num,:].values.tolist()
            del list[0]
            for i in np.arange(len(list)):
                list[i]= list[i]+".NS"
            df = dailydf.loc[d- date.timedelta(days=70):d, list]
            mu = mean_historical_return(df)
            S = CovarianceShrinkage(df).ledoit_wolf()
            ef = EfficientFrontier(mu, S)#,weight_bounds=(-1,1))
            winner_weights = ef.max_sharpe()
            winner_cleaned_weights = ef.clean_weights()
            w=pd.Series(winner_cleaned_weights)
            for lm,ln in zip(list,winner_column_list):
                winner_weightage.loc[num,ln]= w[lm]

# %%
#Calculating return of stocks depending on the number of months input in "holdingperiod" variable
#for backtesting poertfolio returns

holdingdf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]

for i,j in zip(holdingdf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = holdingdf.loc[i,"Date"] + date.timedelta(days=3)
            holdingdf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        holdingdf.loc[i+1,tick]= forw.loc[k,tick]
                        holdingdf.loc[i+1,"date_num"]=4    

holdingdf.sort_index(inplace=True)
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1),inplace=True, drop=True)

for i in holdingdf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        holdingdf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   holdingdf[j]=holdingdf[i]-holdingdf[i].shift(holdingperiod*2-1)
   holdingdf[k]=holdingdf[j]/holdingdf[i].shift(holdingperiod*2-1)*100
   #monthly3df[k+"rsquared"] =monthly3df[k]*monthly3df[k]
   
holdingdf = holdingdf[holdingdf['date_num']== 4]
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1), inplace=True, drop=True)
monthly=pd.DataFrame()
holdingdf.drop(np.arange(1,returnperiod+holdingperiod,1),inplace=True)
holdingdf.reset_index(inplace=True)
del holdingdf["index"]

# %%
#Calculating Backtest returns of winner portfolio
#"winner_test_return" dataframe provides backtested returns 
# for each stock in each of the winner portfolios, for the period of time input in "holdingperiod" return variable
winner_test_return= pd.DataFrame()

for ln in winner_column_list:
    for w,j in zip(winner_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        winner_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

winner_test_return.reset_index(inplace=True)
del winner_test_return["index"]
   
winner_weighted_return= pd.DataFrame()

for ln in winner_column_list:
    winner_weighted_return[ln]= winner_test_return[ln]*winner_weightage[ln]

winner_weighted_return.dropna(inplace=True)

#"winner_weighted_return["Sum"]" dataframe provides total weighted average return for each winner portfolio
winner_weighted_return["Sum"]= winner_weighted_return.loc[:,winner_column_list].sum(axis=1)

# %%
#Calculating Backtest returns of loser portfolio
#"loser_test_return" dataframe provides backtested returns 
# for each stock in each of the loser portfolios, for the period of time input in "holdingperiod" return variable

loser_test_return= pd.DataFrame()

for ln in loser_column_list:
    for w,j in zip(loser_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        loser_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

loser_test_return.reset_index(inplace=True)
del loser_test_return["index"]

loser_weighted_return= pd.DataFrame()

#"loser_weighted_return["Sum"]" dataframe provides total weighted average return for each loser portfolio
loser_weighted_return["Sum"]= loser_test_return.mean(axis=1)

# %%
#Output gives the total return of winner portfolio for each churning period
winner_weighted_return["Sum"]
# Out:
# 0   -6.46423
# Name: Sum, dtype: float64

# %%
#Output gives the total return of loser for each churning period
loser_weighted_return["Sum"]
# Out:
# 0   -16.761095
# Name: Sum, dtype: float64

# %%
avg=winner_weighted_return["Sum"].mean()
std=winner_weighted_return["Sum"].std()
print("Winner Portfolio mean return:",avg)
print("Winner Portfolio Std. dev.:", std)
# Out:
# Winner Portfolio mean return: -6.464229973459846
# Winner Portfolio Std. dev.: nan

# %%
avg=loser_weighted_return["Sum"].mean()
std=loser_weighted_return["Sum"].std()
print("Loser Portfolio mean return:",avg)
print("Loser Portfolio Std. dev.:", std)
# Out:
# Loser Portfolio mean return: -16.761095198438568
# Loser Portfolio Std. dev.: nan

# %%
sn.set_theme()
plt.title('Winner Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-50,100,step=5))
plt.xticks(np.arange(0,100,step=1))
plt.scatter(winner_weighted_return.index, winner_weighted_return["Sum"])
plt.show()

# %%
sn.set_theme()
plt.title('Loser Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-50,100,step=5))
plt.xticks(np.arange(0,100,step=1))
plt.scatter(loser_weighted_return.index, loser_weighted_return["Sum"])
plt.show()

# %%
winner_portfolio
# Out:
#         Date       W1          W2      W3    W4         W5          W6  \
# 0 2023-01-27      PNB  JINDALSTEL  INDIGO   IOC  TATASTEEL        ONGC
# 1 2023-02-24  SIEMENS         ITC    GAIL  ONGC   SHREECEM  BAJAJ-AUTO
#
#           W7        W8        W9       W10
# 0  HINDPETRO      VEDL  GODREJCP  HDFCLIFE
# 1   GODREJCP  BOSCHLTD  CHOLAFIN        LT
