# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import yfinance as yf
import random
import os
import matplotlib.pyplot as plt
from datetime import datetime as dt
import datetime as date
plt.rcParams["figure.figsize"] = (20,10)
import seaborn as sn
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import datetime

import pandas as pd
import numpy as np
import time
from datetime import datetime
import math
import requests
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, CrosshairTool, HoverTool, NumeralTickFormatter
from bokeh.plotting import figure
from bokeh.layouts import column, row
from bokeh.transform import cumsum

# %%
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier

# %%
# download csv from url
#url = 'https://archives.nseindia.com/content/indices/ind_nifty100list.csv'
#nifty100 = pd.read_csv(url)
#nifty100.to_csv('ind_nifty100list.csv', index=False)

# %%
symbol= pd.read_csv("ind_nifty100list.csv")
symbol["ticker"] = symbol["Symbol"] + ".NS"
ticker= symbol['ticker'].values.tolist()
ticker
# Out:
# ['ABB.NS',
#  'ADANIENSOL.NS',
#  'ADANIENT.NS',
#  'ADANIGREEN.NS',
#  'ADANIPORTS.NS',
#  'ADANIPOWER.NS',
#  'ATGL.NS',
#  'AMBUJACEM.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'DMART.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BAJAJHLDNG.NS',
#  'BANKBARODA.NS',
#  'BERGEPAINT.NS',
#  'BEL.NS',
#  'BPCL.NS',
#  'BHARTIARTL.NS',
#  'BOSCHLTD.NS',
#  'BRITANNIA.NS',
#  'CANBK.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'COLPAL.NS',
#  'DLF.NS',
#  'DABUR.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GAIL.NS',
#  'GODREJCP.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HAVELLS.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HAL.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'ICICIGI.NS',
#  'ICICIPRULI.NS',
#  'ITC.NS',
#  'IOC.NS',
#  'IRCTC.NS',
#  'IRFC.NS',
#  'INDUSINDBK.NS',
#  'NAUKRI.NS',
#  'INFY.NS',
#  'INDIGO.NS',
#  'JSWSTEEL.NS',
#  'JINDALSTEL.NS',
#  'JIOFIN.NS',
#  'KOTAKBANK.NS',
#  'LTIM.NS',
#  'LT.NS',
#  'LICI.NS',
#  'M&M.NS',
#  'MARICO.NS',
#  'MARUTI.NS',
#  'NTPC.NS',
#  'NESTLEIND.NS',
#  'ONGC.NS',
#  'PIDILITIND.NS',
#  'PFC.NS',
#  'POWERGRID.NS',
#  'PNB.NS',
#  'RECLTD.NS',
#  'RELIANCE.NS',
#  'SBICARD.NS',
#  'SBILIFE.NS',
#  'SRF.NS',
#  'MOTHERSON.NS',
#  'SHREECEM.NS',
#  'SHRIRAMFIN.NS',
#  'SIEMENS.NS',
#  'SBIN.NS',
#  'SUNPHARMA.NS',
#  'TVSMOTOR.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TATAMTRDVR.NS',
#  'TATAMOTORS.NS',
#  'TATAPOWER.NS',
#  'TATASTEEL.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'TORNTPHARM.NS',
#  'TRENT.NS',
#  'ULTRACEMCO.NS',
#  'UNITDSPR.NS',
#  'VBL.NS',
#  'VEDL.NS',
#  'WIPRO.NS',
#  'ZOMATO.NS',
#  'ZYDUSLIFE.NS']

# %%
sd = yf.download(ticker, interval='1d')
sd.reset_index(inplace=True)
# Out:
# Exception in thread Thread-308:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-310:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*                      3%                       ]  3 of 101 completed
# Exception in thread Thread-314:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-315:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**                     5%                       ]  5 of 101 completed
# Exception in thread Thread-317:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
# Exception in thread Thread-318:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*****                 10%                       ]  10 of 101 completed
# Exception in thread Thread-324:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*********             18%                       ]  18 of 101 completed
# Exception in thread Thread-333:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-335:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*********             19%                       ]  19 of 101 completed
# Exception in thread Thread-336:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********            21%                       ]  21 of 101 completed
# Exception in thread Thread-340:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [***********           23%                       ]  23 of 101 completed
# Exception in thread Thread-344:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**************        29%                       ]  29 of 101 completed
# Exception in thread Thread-350:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [********************* 44%                       ]  44 of 101 completed
# Exception in thread Thread-367:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************47%                       ]  47 of 101 completed
# Exception in thread Thread-369:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************49%                       ]  49 of 101 completed
# Exception in thread Thread-372:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************50%                       ]  50 of 101 completed
# Exception in thread Thread-375:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************51%                       ]  52 of 101 completed
# Exception in thread Thread-377:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************56%**                     ]  57 of 101 completed
# Exception in thread Thread-384:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************59%***                    ]  60 of 101 completed
# Exception in thread Thread-388:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************62%*****                  ]  63 of 101 completed
# Exception in thread Thread-391:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
# Exception in thread Thread-392:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************68%********               ]  69 of 101 completed
# Exception in thread Thread-399:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-402:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************71%*********              ]  72 of 101 completed
# Exception in thread Thread-406:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
# Exception in thread Thread-404:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************74%***********            ]  75 of 101 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11488\1324951053.py in <module>
# ----> 1 sd = yf.download(ticker, interval='1d')
#       2 sd.reset_index(inplace=True)
#
# ~\anaconda3\lib\site-packages\yfinance\multi.py in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     110                                    rounding=rounding, timeout=timeout)
#     111         while len(shared._DFS) < len(tickers):
# --> 112             _time.sleep(0.01)
#     113
#     114     # download synchronously
#
# KeyboardInterrupt:

# %%
symbol["NS"]= ".NS"
symbol["ticker"] = symbol["Symbol"] + symbol["NS"]
symbol
# Out:
#                                           Company Name  \
# 0                                       ABB India Ltd.
# 1                          Adani Energy Solutions Ltd.
# 2                               Adani Enterprises Ltd.
# 3                              Adani Green Energy Ltd.
# 4           Adani Ports and Special Economic Zone Ltd.
# 5                                     Adani Power Ltd.
# 6                                 Adani Total Gas Ltd.
# 7                                  Ambuja Cements Ltd.
# 8                     Apollo Hospitals Enterprise Ltd.
# 9                                    Asian Paints Ltd.
# 10                              Avenue Supermarts Ltd.
# 11                                      Axis Bank Ltd.
# 12                                     Bajaj Auto Ltd.
# 13                                  Bajaj Finance Ltd.
# 14                                  Bajaj Finserv Ltd.
# 15                    Bajaj Holdings & Investment Ltd.
# 16                                      Bank of Baroda
# 17                            Berger Paints India Ltd.
# 18                             Bharat Electronics Ltd.
# 19                   Bharat Petroleum Corporation Ltd.
# 20                                  Bharti Airtel Ltd.
# 21                                          Bosch Ltd.
# 22                           Britannia Industries Ltd.
# 23                                         Canara Bank
# 24   Cholamandalam Investment and Finance Company Ltd.
# 25                                          Cipla Ltd.
# 26                                     Coal India Ltd.
# 27                      Colgate Palmolive (India) Ltd.
# 28                                            DLF Ltd.
# 29                                    Dabur India Ltd.
# 30                            Divi's Laboratories Ltd.
# 31                       Dr. Reddy's Laboratories Ltd.
# 32                                  Eicher Motors Ltd.
# 33                                   GAIL (India) Ltd.
# 34                       Godrej Consumer Products Ltd.
# 35                              Grasim Industries Ltd.
# 36                               HCL Technologies Ltd.
# 37                                      HDFC Bank Ltd.
# 38                    HDFC Life Insurance Company Ltd.
# 39                                  Havells India Ltd.
# 40                                  Hero MotoCorp Ltd.
# 41                            Hindalco Industries Ltd.
# 42                          Hindustan Aeronautics Ltd.
# 43                             Hindustan Unilever Ltd.
# 44                                     ICICI Bank Ltd.
# 45        ICICI Lombard General Insurance Company Ltd.
# 46        ICICI Prudential Life Insurance Company Ltd.
# 47                                            ITC Ltd.
# 48                         Indian Oil Corporation Ltd.
# 49   Indian Railway Catering And Tourism Corporatio...
# 50             Indian Railway Finance Corporation Ltd.
# 51                                  IndusInd Bank Ltd.
# 52                              Info Edge (India) Ltd.
# 53                                        Infosys Ltd.
# 54                            InterGlobe Aviation Ltd.
# 55                                      JSW Steel Ltd.
# 56                           Jindal Steel & Power Ltd.
# 57                         Jio Financial Services Ltd.
# 58                            Kotak Mahindra Bank Ltd.
# 59                                    LTIMindtree Ltd.
# 60                                Larsen & Toubro Ltd.
# 61                 Life Insurance Corporation of India
# 62                            Mahindra & Mahindra Ltd.
# 63                                         Marico Ltd.
# 64                            Maruti Suzuki India Ltd.
# 65                                           NTPC Ltd.
# 66                                   Nestle India Ltd.
# 67                  Oil & Natural Gas Corporation Ltd.
# 68                            Pidilite Industries Ltd.
# 69                      Power Finance Corporation Ltd.
# 70                Power Grid Corporation of India Ltd.
# 71                                Punjab National Bank
# 72                                            REC Ltd.
# 73                            Reliance Industries Ltd.
# 74                 SBI Cards and Payment Services Ltd.
# 75                     SBI Life Insurance Company Ltd.
# 76                                            SRF Ltd.
# 77            Samvardhana Motherson International Ltd.
# 78                                   Shree Cement Ltd.
# 79                                Shriram Finance Ltd.
# 80                                        Siemens Ltd.
# 81                                 State Bank of India
# 82                  Sun Pharmaceutical Industries Ltd.
# 83                              TVS Motor Company Ltd.
# 84                      Tata Consultancy Services Ltd.
# 85                         Tata Consumer Products Ltd.
# 86                                 Tata Motors Ltd DVR
# 87                                    Tata Motors Ltd.
# 88                                 Tata Power Co. Ltd.
# 89                                     Tata Steel Ltd.
# 90                                  Tech Mahindra Ltd.
# 91                                  Titan Company Ltd.
# 92                        Torrent Pharmaceuticals Ltd.
# 93                                          Trent Ltd.
# 94                               UltraTech Cement Ltd.
# 95                                 United Spirits Ltd.
# 96                                Varun Beverages Ltd.
# 97                                        Vedanta Ltd.
# 98                                          Wipro Ltd.
# 99                                         Zomato Ltd.
# 100                            Zydus Lifesciences Ltd.
#
#                            Industry      Symbol Series     ISIN Code  \
# 0                     Capital Goods         ABB     EQ  INE117A01022
# 1                             Power  ADANIENSOL     EQ  INE931S01010
# 2                   Metals & Mining    ADANIENT     EQ  INE423A01024
# 3                             Power  ADANIGREEN     EQ  INE364U01010
# 4                          Services  ADANIPORTS     EQ  INE742F01042
# 5                             Power  ADANIPOWER     EQ  INE814H01011
# 6        Oil Gas & Consumable Fuels        ATGL     EQ  INE399L01023
# 7            Construction Materials   AMBUJACEM     EQ  INE079A01024
# 8                        Healthcare  APOLLOHOSP     EQ  INE437A01024
# 9                 Consumer Durables  ASIANPAINT     EQ  INE021A01026
# 10                Consumer Services       DMART     EQ  INE192R01011
# 11               Financial Services    AXISBANK     EQ  INE238A01034
# 12   Automobile and Auto Components  BAJAJ-AUTO     EQ  INE917I01010
# 13               Financial Services  BAJFINANCE     EQ  INE296A01024
# 14               Financial Services  BAJAJFINSV     EQ  INE918I01026
# 15               Financial Services  BAJAJHLDNG     EQ  INE118A01012
# 16               Financial Services  BANKBARODA     EQ  INE028A01039
# 17                Consumer Durables  BERGEPAINT     EQ  INE463A01038
# 18                    Capital Goods         BEL     EQ  INE263A01024
# 19       Oil Gas & Consumable Fuels        BPCL     EQ  INE029A01011
# 20                Telecommunication  BHARTIARTL     EQ  INE397D01024
# 21   Automobile and Auto Components    BOSCHLTD     EQ  INE323A01026
# 22       Fast Moving Consumer Goods   BRITANNIA     EQ  INE216A01030
# 23               Financial Services       CANBK     EQ  INE476A01022
# 24               Financial Services    CHOLAFIN     EQ  INE121A01024
# 25                       Healthcare       CIPLA     EQ  INE059A01026
# 26       Oil Gas & Consumable Fuels   COALINDIA     EQ  INE522F01014
# 27       Fast Moving Consumer Goods      COLPAL     EQ  INE259A01022
# 28                           Realty         DLF     EQ  INE271C01023
# 29       Fast Moving Consumer Goods       DABUR     EQ  INE016A01026
# 30                       Healthcare    DIVISLAB     EQ  INE361B01024
# 31                       Healthcare     DRREDDY     EQ  INE089A01023
# 32   Automobile and Auto Components   EICHERMOT     EQ  INE066A01021
# 33       Oil Gas & Consumable Fuels        GAIL     EQ  INE129A01019
# 34       Fast Moving Consumer Goods    GODREJCP     EQ  INE102D01028
# 35           Construction Materials      GRASIM     EQ  INE047A01021
# 36           Information Technology     HCLTECH     EQ  INE860A01027
# 37               Financial Services    HDFCBANK     EQ  INE040A01034
# 38               Financial Services    HDFCLIFE     EQ  INE795G01014
# 39                Consumer Durables     HAVELLS     EQ  INE176B01034
# 40   Automobile and Auto Components  HEROMOTOCO     EQ  INE158A01026
# 41                  Metals & Mining    HINDALCO     EQ  INE038A01020
# 42                    Capital Goods         HAL     EQ  INE066F01020
# 43       Fast Moving Consumer Goods  HINDUNILVR     EQ  INE030A01027
# 44               Financial Services   ICICIBANK     EQ  INE090A01021
# 45               Financial Services     ICICIGI     EQ  INE765G01017
# 46               Financial Services  ICICIPRULI     EQ  INE726G01019
# 47       Fast Moving Consumer Goods         ITC     EQ  INE154A01025
# 48       Oil Gas & Consumable Fuels         IOC     EQ  INE242A01010
# 49                Consumer Services       IRCTC     EQ  INE335Y01020
# 50               Financial Services        IRFC     EQ  INE053F01010
# 51               Financial Services  INDUSINDBK     EQ  INE095A01012
# 52                Consumer Services      NAUKRI     EQ  INE663F01024
# 53           Information Technology        INFY     EQ  INE009A01021
# 54                         Services      INDIGO     EQ  INE646L01027
# 55                  Metals & Mining    JSWSTEEL     EQ  INE019A01038
# 56                  Metals & Mining  JINDALSTEL     EQ  INE749A01030
# 57               Financial Services      JIOFIN     EQ  INE758E01017
# 58               Financial Services   KOTAKBANK     EQ  INE237A01028
# 59           Information Technology        LTIM     EQ  INE214T01019
# 60                     Construction          LT     EQ  INE018A01030
# 61               Financial Services        LICI     EQ  INE0J1Y01017
# 62   Automobile and Auto Components         M&M     EQ  INE101A01026
# 63       Fast Moving Consumer Goods      MARICO     EQ  INE196A01026
# 64   Automobile and Auto Components      MARUTI     EQ  INE585B01010
# 65                            Power        NTPC     EQ  INE733E01010
# 66       Fast Moving Consumer Goods   NESTLEIND     EQ  INE239A01024
# 67       Oil Gas & Consumable Fuels        ONGC     EQ  INE213A01029
# 68                        Chemicals  PIDILITIND     EQ  INE318A01026
# 69               Financial Services         PFC     EQ  INE134E01011
# 70                            Power   POWERGRID     EQ  INE752E01010
# 71               Financial Services         PNB     EQ  INE160A01022
# 72               Financial Services      RECLTD     EQ  INE020B01018
# 73       Oil Gas & Consumable Fuels    RELIANCE     EQ  INE002A01018
# 74               Financial Services     SBICARD     EQ  INE018E01016
# 75               Financial Services     SBILIFE     EQ  INE123W01016
# 76                        Chemicals         SRF     EQ  INE647A01010
# 77   Automobile and Auto Components   MOTHERSON     EQ  INE775A01035
# 78           Construction Materials    SHREECEM     EQ  INE070A01015
# 79               Financial Services  SHRIRAMFIN     EQ  INE721A01013
# 80                    Capital Goods     SIEMENS     EQ  INE003A01024
# 81               Financial Services        SBIN     EQ  INE062A01020
# 82                       Healthcare   SUNPHARMA     EQ  INE044A01036
# 83   Automobile and Auto Components    TVSMOTOR     EQ  INE494B01023
# 84           Information Technology         TCS     EQ  INE467B01029
# 85       Fast Moving Consumer Goods  TATACONSUM     EQ  INE192A01025
# 86   Automobile and Auto Components  TATAMTRDVR     EQ  IN9155A01020
# 87   Automobile and Auto Components  TATAMOTORS     EQ  INE155A01022
# 88                            Power   TATAPOWER     EQ  INE245A01021
# 89                  Metals & Mining   TATASTEEL     EQ  INE081A01020
# 90           Information Technology       TECHM     EQ  INE669C01036
# 91                Consumer Durables       TITAN     EQ  INE280A01028
# 92                       Healthcare  TORNTPHARM     EQ  INE685A01028
# 93                Consumer Services       TRENT     EQ  INE849A01020
# 94           Construction Materials  ULTRACEMCO     EQ  INE481G01011
# 95       Fast Moving Consumer Goods    UNITDSPR     EQ  INE854D01024
# 96       Fast Moving Consumer Goods         VBL     EQ  INE200M01021
# 97                  Metals & Mining        VEDL     EQ  INE205A01025
# 98           Information Technology       WIPRO     EQ  INE075A01022
# 99                Consumer Services      ZOMATO     EQ  INE758T01015
# 100                      Healthcare   ZYDUSLIFE     EQ  INE010B01027
#
#             ticker   NS
# 0           ABB.NS  .NS
# 1    ADANIENSOL.NS  .NS
# 2      ADANIENT.NS  .NS
# 3    ADANIGREEN.NS  .NS
# 4    ADANIPORTS.NS  .NS
# 5    ADANIPOWER.NS  .NS
# 6          ATGL.NS  .NS
# 7     AMBUJACEM.NS  .NS
# 8    APOLLOHOSP.NS  .NS
# 9    ASIANPAINT.NS  .NS
# 10        DMART.NS  .NS
# 11     AXISBANK.NS  .NS
# 12   BAJAJ-AUTO.NS  .NS
# 13   BAJFINANCE.NS  .NS
# 14   BAJAJFINSV.NS  .NS
# 15   BAJAJHLDNG.NS  .NS
# 16   BANKBARODA.NS  .NS
# 17   BERGEPAINT.NS  .NS
# 18          BEL.NS  .NS
# 19         BPCL.NS  .NS
# 20   BHARTIARTL.NS  .NS
# 21     BOSCHLTD.NS  .NS
# 22    BRITANNIA.NS  .NS
# 23        CANBK.NS  .NS
# 24     CHOLAFIN.NS  .NS
# 25        CIPLA.NS  .NS
# 26    COALINDIA.NS  .NS
# 27       COLPAL.NS  .NS
# 28          DLF.NS  .NS
# 29        DABUR.NS  .NS
# 30     DIVISLAB.NS  .NS
# 31      DRREDDY.NS  .NS
# 32    EICHERMOT.NS  .NS
# 33         GAIL.NS  .NS
# 34     GODREJCP.NS  .NS
# 35       GRASIM.NS  .NS
# 36      HCLTECH.NS  .NS
# 37     HDFCBANK.NS  .NS
# 38     HDFCLIFE.NS  .NS
# 39      HAVELLS.NS  .NS
# 40   HEROMOTOCO.NS  .NS
# 41     HINDALCO.NS  .NS
# 42          HAL.NS  .NS
# 43   HINDUNILVR.NS  .NS
# 44    ICICIBANK.NS  .NS
# 45      ICICIGI.NS  .NS
# 46   ICICIPRULI.NS  .NS
# 47          ITC.NS  .NS
# 48          IOC.NS  .NS
# 49        IRCTC.NS  .NS
# 50         IRFC.NS  .NS
# 51   INDUSINDBK.NS  .NS
# 52       NAUKRI.NS  .NS
# 53         INFY.NS  .NS
# 54       INDIGO.NS  .NS
# 55     JSWSTEEL.NS  .NS
# 56   JINDALSTEL.NS  .NS
# 57       JIOFIN.NS  .NS
# 58    KOTAKBANK.NS  .NS
# 59         LTIM.NS  .NS
# 60           LT.NS  .NS
# 61         LICI.NS  .NS
# 62          M&M.NS  .NS
# 63       MARICO.NS  .NS
# 64       MARUTI.NS  .NS
# 65         NTPC.NS  .NS
# 66    NESTLEIND.NS  .NS
# 67         ONGC.NS  .NS
# 68   PIDILITIND.NS  .NS
# 69          PFC.NS  .NS
# 70    POWERGRID.NS  .NS
# 71          PNB.NS  .NS
# 72       RECLTD.NS  .NS
# 73     RELIANCE.NS  .NS
# 74      SBICARD.NS  .NS
# 75      SBILIFE.NS  .NS
# 76          SRF.NS  .NS
# 77    MOTHERSON.NS  .NS
# 78     SHREECEM.NS  .NS
# 79   SHRIRAMFIN.NS  .NS
# 80      SIEMENS.NS  .NS
# 81         SBIN.NS  .NS
# 82    SUNPHARMA.NS  .NS
# 83     TVSMOTOR.NS  .NS
# 84          TCS.NS  .NS
# 85   TATACONSUM.NS  .NS
# 86   TATAMTRDVR.NS  .NS
# 87   TATAMOTORS.NS  .NS
# 88    TATAPOWER.NS  .NS
# 89    TATASTEEL.NS  .NS
# 90        TECHM.NS  .NS
# 91        TITAN.NS  .NS
# 92   TORNTPHARM.NS  .NS
# 93        TRENT.NS  .NS
# 94   ULTRACEMCO.NS  .NS
# 95     UNITDSPR.NS  .NS
# 96          VBL.NS  .NS
# 97         VEDL.NS  .NS
# 98        WIPRO.NS  .NS
# 99       ZOMATO.NS  .NS
# 100   ZYDUSLIFE.NS  .NS

# %%
pricechg = symbol["Symbol"] + " pricechg"
percentchg = symbol["Symbol"] #+ " percentchg"
ticker = symbol['ticker']
pricechg= pricechg.values.tolist()
percentchg= percentchg.values.tolist()
ticker= ticker.values.tolist()

# %%
sd = yf.download(ticker, interval='1d')

data= sd['Adj Close']
# Out:
# Exception in thread Thread-207:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [                       0%                       ]
# Exception in thread Thread-209:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*                      3%                       ]  3 of 101 completed
# Exception in thread Thread-213:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
# Exception in thread Thread-214:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**                     5%                       ]  5 of 101 completed
# Exception in thread Thread-216:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
# Exception in thread Thread-217:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*****                 10%                       ]  10 of 101 completed
# Exception in thread Thread-223:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*********             18%                       ]  18 of 101 completed
# Exception in thread Thread-232:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [*********             19%                       ]  19 of 101 completed
# Exception in thread Thread-234:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********            20%                       ]  20 of 101 completed
# Exception in thread Thread-235:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [***********           22%                       ]  22 of 101 completed
# Exception in thread Thread-239:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [************          24%                       ]  24 of 101 completed
# Exception in thread Thread-243:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**************        29%                       ]  29 of 101 completed
# Exception in thread Thread-249:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************45%                       ]  45 of 101 completed
# Exception in thread Thread-266:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************47%                       ]  47 of 101 completed
# Exception in thread Thread-268:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************49%                       ]  49 of 101 completed
# Exception in thread Thread-271:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************50%                       ]  51 of 101 completed
# Exception in thread Thread-274:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-276:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************57%**                     ]  58 of 101 completed
# Exception in thread Thread-283:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************60%****                   ]  61 of 101 completed
# Exception in thread Thread-287:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************62%*****                  ]  63 of 101 completed
# Exception in thread Thread-290:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
# Exception in thread Thread-291:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************68%********               ]  69 of 101 completed
# Exception in thread Thread-298:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************69%********               ]  70 of 101 completed
# Exception in thread Thread-301:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************71%*********              ]  72 of 101 completed
# Exception in thread Thread-303:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# Exception in thread Thread-305:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\admin\anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\multi.py", line 202, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "C:\Users\admin\anaconda3\lib\site-packages\yfinance\base.py", line 279, in history
#     df.index = df.index.tz_localize("UTC").tz_convert(
# AttributeError: 'Index' object has no attribute 'tz_localize'
# [**********************74%***********            ]  75 of 101 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11488\3730894222.py in <module>
# ----> 1 sd = yf.download(ticker, interval='1d')
#       2
#       3 data= sd['Adj Close']
#
# ~\anaconda3\lib\site-packages\yfinance\multi.py in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     110                                    rounding=rounding, timeout=timeout)
#     111         while len(shared._DFS) < len(tickers):
# --> 112             _time.sleep(0.01)
#     113
#     114     # download synchronously
#
# KeyboardInterrupt:

# %%
# This coding block requires inputs for each of the variables as described below-
# returnperiod- No. of months over which the returns of stocks is measured to create a portfolio
# holdingperiod- Following no. of months over which the stocks in the portfolio will be held for
# sdate_input- Starting date from where the data for each stock should start (Starting date must fall on a Monday)
# fdate_input- Ending date for where the data for each stock should end (Ending date must fall on a Friday)
# input for dates should be in the following format -> "YYYY-MM-DD"
returnperiod= 3
holdingperiod= 1

sdate_input= datetime.date.today().month - (holdingperiod + returnperiod)
if sdate_input <= 0:
    sdate_input = datetime.date.today().replace(month=sdate_input+12, day=1, year=datetime.date.today().year-1)
else:
    sdate_input = datetime.date.today().replace(month=sdate_input, day=1)

fdate_input= datetime.date.today().month - (holdingperiod)
if fdate_input <= 0:
    fdate_input = datetime.date.today().replace(month=fdate_input+12, day=1, year=datetime.date.today().year-1)
else:
    fdate_input = datetime.date.today().replace(month=fdate_input, day=1)

# sdate_input = sdate_input + datetime.timedelta(days=-sdate_input.weekday(), weeks=1)

# first monday of the month
sdate_input = str(sdate_input + datetime.timedelta(days=-sdate_input.weekday(), weeks=1))
# last friday of the month
fdate_input = str(fdate_input + datetime.timedelta(days=-fdate_input.weekday(), weeks=4) + datetime.timedelta(days=4))
print(sdate_input, fdate_input)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13940\2541798951.py in <module>
#       8 holdingperiod= 1
#       9
# ---> 10 sdate_input= datetime.date.today().month - (holdingperiod + returnperiod)
#      11 if sdate_input <= 0:
#      12     sdate_input = datetime.date.today().replace(month=sdate_input+12, day=1, year=datetime.date.today().year-1)
#
# AttributeError: 'method_descriptor' object has no attribute 'today'

# %%
import pytz

start = pytz.utc.localize(dt.strptime(sdate_input, '%Y-%m-%d'))
finish = pytz.utc.localize(dt.strptime(fdate_input,'%Y-%m-%d'))

forw = data.loc[start:finish]
dailydf = data.loc[start:finish]
forw.reset_index(inplace=True)
forw['date_num'] = forw['Date'].dt.weekday
weeklydf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
weeklydfcopy = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
returndf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13940\377450896.py in <module>
#       1 import pytz
#       2
# ----> 3 start = pytz.utc.localize(dt.strptime(sdate_input, '%Y-%m-%d'))
#       4 finish = pytz.utc.localize(dt.strptime(fdate_input,'%Y-%m-%d'))
#       5
#
# NameError: name 'sdate_input' is not defined

# %%
weeklydfcopy.set_index(np.arange(len(weeklydfcopy.index)), inplace=True, drop=True)

# %%
#Calculating return of stocks depending on the number of months input in "returnperiod" variable
#for creating porfolios 
for i,j in zip(returndf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = returndf.loc[i,"Date"] + datetime.timedelta(days=3)
            returndf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        returndf.loc[i+1,tick]= forw.loc[k,tick]
                        returndf.loc[i+1,"date_num"]=4
    
returndf.sort_index(inplace=True)
returndf.set_index(np.arange(1,len(returndf.index)+1,1),inplace=True, drop=True)

for i in returndf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        returndf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   returndf[j]=returndf[i]-returndf[i].shift(returnperiod*2-1)
   returndf[k]=returndf[j]/returndf[i].shift(returnperiod*2-1)*100
   
returndf = returndf[returndf["date_num"]==4]
returndf.set_index(np.arange(1,len(returndf.index)+1,1), inplace=True, drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13940\918149635.py in <module>
#       1 #Calculating return of stocks depending on the number of months input in "returnperiod" variable
#       2 #for creating porfolios
# ----> 3 for i,j in zip(returndf.index,weeklydfcopy.index):
#       4     if j == weeklydfcopy.index[-1]:
#       5         break
#
# NameError: name 'returndf' is not defined

# %%
returndf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13940\3978715946.py in <module>
# ----> 1 returndf
#
# NameError: name 'returndf' is not defined

# %%
cov=returndf.cov() 
cov

# %%
#Portfolio formation
winner_portfolio= pd.DataFrame()
loser_portfolio= pd.DataFrame() 

# Portfolio of top 10 stocks made
for i in returndf.index:

    winner_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"]

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W1']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W2']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W3']= j
            returndf.loc[i,j]= None
    
    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W4']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W5']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W6']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W7']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W8']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W9']= j
            returndf.loc[i,j]= None

    max= returndf.loc[i,percentchg].max()
    for j in percentchg:
        if returndf.loc[i,j]== max:
            winner_portfolio.loc[i,'W10']= j
            returndf.loc[i,j]= None

# Portfolio of bottom 10 stocks made
for i in returndf.index:

    loser_portfolio.loc[i,'Date'] = returndf.loc[i,"Date"] 

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L1']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L2']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L3']= j
            returndf.loc[i,j]= None
    
    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L4']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L5']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L6']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L7']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L8']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L9']= j
            returndf.loc[i,j]= None

    min= returndf.loc[i,percentchg].min()
    for j in percentchg:
        if returndf.loc[i,j]== min:
            loser_portfolio.loc[i,'L10']= j
            returndf.loc[i,j]= None


winner_portfolio.dropna(inplace=True)
winner_portfolio.reset_index(inplace=True)
del winner_portfolio["index"]

winner_weightage = pd.DataFrame()

winner_column_list=winner_portfolio.columns.values.tolist()
del winner_column_list[0]

loser_portfolio.dropna(inplace=True)
loser_portfolio.reset_index(inplace=True)
del loser_portfolio["index"]

loser_weightage = pd.DataFrame()

loser_column_list=loser_portfolio.columns.values.tolist()
del loser_column_list[0]

# %% [markdown]
# ## Get winner and loser portfolio weightage

# %%
#Calculating weightage for winner portfolio using mean variance optimization
#To check the weightage dataframe print "winner_weightage" variable

for num in winner_portfolio.index:
    for d in dailydf.index:
        df = pd.DataFrame()
        if winner_portfolio.loc[num,"Date"] == d:
            list=winner_portfolio.loc[num,:].values.tolist()
            del list[0]
            for i in np.arange(len(list)):
                list[i]= list[i]+".NS"
            df = dailydf.loc[d- date.timedelta(days=70):d, list]
            mu = mean_historical_return(df)
            S = CovarianceShrinkage(df).ledoit_wolf()
            ef = EfficientFrontier(mu, S)#,weight_bounds=(-1,1))
            winner_weights = ef.max_sharpe()
            winner_cleaned_weights = ef.clean_weights()
            w=pd.Series(winner_cleaned_weights)
            for lm,ln in zip(list,winner_column_list):
                winner_weightage.loc[num,ln]= w[lm]

for num in loser_portfolio.index:
    for d in dailydf.index:
        df = pd.DataFrame()
        if loser_portfolio.loc[num,"Date"] == d:
            list=loser_portfolio.loc[num,:].values.tolist()
            del list[0]
            for i in np.arange(len(list)):
                list[i]= list[i]+".NS"
            df = dailydf.loc[d- date.timedelta(days=70):d, list]
            mu = -mean_historical_return(df)
            S = CovarianceShrinkage(df).ledoit_wolf()
            ef = EfficientFrontier(mu, S)#,weight_bounds=(-1,1))
            loser_weights = ef.max_sharpe()
            loser_cleaned_weights = ef.clean_weights()
            w=pd.Series(loser_cleaned_weights)
            for lm,ln in zip(list,loser_column_list):
                loser_weightage.loc[num,ln]= w[lm]

# %%
#Calculating return of stocks depending on the number of months input in "holdingperiod" variable
#for backtesting poertfolio returns

holdingdf = forw[(forw['date_num']== 0) | (forw['date_num']== 4)]

for i,j in zip(holdingdf.index,weeklydfcopy.index):
    if j == weeklydfcopy.index[-1]:
        break
    if weeklydfcopy.loc[j,"date_num"]==0:
        if weeklydfcopy.loc[j+1,"date_num"]==0:
            #print(i)
            d = holdingdf.loc[i,"Date"] + date.timedelta(days=3)
            holdingdf.loc[i+1,"Date"]= d
            for k in forw.index:
                if forw.loc[k,"Date"]==d:
                    for tick in ticker:
                        holdingdf.loc[i+1,tick]= forw.loc[k,tick]
                        holdingdf.loc[i+1,"date_num"]=4    

holdingdf.sort_index(inplace=True)
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1),inplace=True, drop=True)

for i in holdingdf.index:
    if i==1:
        continue
    if i%8==0:
        continue
    if i%8==1:
        continue
    else:
        holdingdf.drop(i,inplace=True)

for i,j,k in zip(ticker, pricechg, percentchg):
    
   holdingdf[j]=holdingdf[i]-holdingdf[i].shift(holdingperiod*2-1)
   holdingdf[k]=holdingdf[j]/holdingdf[i].shift(holdingperiod*2-1)*100
   #monthly3df[k+"rsquared"] =monthly3df[k]*monthly3df[k]
   
holdingdf = holdingdf[holdingdf['date_num']== 4]
holdingdf.set_index(np.arange(1,len(holdingdf.index)+1,1), inplace=True, drop=True)
monthly=pd.DataFrame()
holdingdf.drop(np.arange(1,returnperiod+holdingperiod,1),inplace=True)
holdingdf.reset_index(inplace=True)
del holdingdf["index"]

# %%
#Calculating Backtest returns of winner portfolio
#"winner_test_return" dataframe provides backtested returns 
# for each stock in each of the winner portfolios, for the period of time input in "holdingperiod" return variable
winner_test_return= pd.DataFrame()

for ln in winner_column_list:
    for w,j in zip(winner_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        winner_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

winner_test_return.reset_index(inplace=True)
del winner_test_return["index"]
   
winner_weighted_return= pd.DataFrame()

for ln in winner_column_list:
    winner_weighted_return[ln]= winner_test_return[ln]*winner_weightage[ln]

winner_weighted_return.dropna(inplace=True)

#"winner_weighted_return["Sum"]" dataframe provides total weighted average return for each winner portfolio
winner_weighted_return["Sum"]= winner_weighted_return.loc[:,winner_column_list].sum(axis=1)

# %%
#Calculating Backtest returns of loser portfolio
#"loser_test_return" dataframe provides backtested returns 
# for each stock in each of the loser portfolios, for the period of time input in "holdingperiod" return variable

loser_test_return= pd.DataFrame()

for ln in loser_column_list:
    for w,j in zip(loser_portfolio[ln],holdingdf.index):
        k= holdingdf.columns.get_loc(w)
        loser_test_return.loc[j,ln]= holdingdf.iloc[j,k] 
        if j == holdingdf.index[-1]:
            break

loser_test_return.reset_index(inplace=True)
del loser_test_return["index"]

loser_weighted_return= pd.DataFrame()

#"loser_weighted_return["Sum"]" dataframe provides total weighted average return for each loser portfolio
loser_weighted_return["Sum"]= loser_test_return.mean(axis=1)

# %%
#Output gives the total return of winner portfolio for each churning period
winner_weighted_return["Sum"]

# %%
#Output gives the total return of loser for each churning period
loser_weighted_return["Sum"]

# %%
avg=winner_weighted_return["Sum"].mean()
std=winner_weighted_return["Sum"].std()
print("Winner Portfolio mean return:",avg)
print("Winner Portfolio Std. dev.:", std)

# %%
avg=loser_weighted_return["Sum"].mean()
std=loser_weighted_return["Sum"].std()
print("Loser Portfolio mean return:",avg)
print("Loser Portfolio Std. dev.:", std)

# %%
sn.set_theme()
plt.title('Winner Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-500, 500,step=10))
plt.xticks(np.arange(0,1000,step=1))
plt.scatter(winner_weighted_return.index, winner_weighted_return["Sum"])
plt.show()

# %%
sn.set_theme()
plt.title('Loser Portfolio plot')
plt.xlabel('No. of months')
plt.ylabel('Return in each churn')
plt.yticks(np.arange(-50,100,step=5))
plt.xticks(np.arange(0,100,step=1))
plt.scatter(loser_weighted_return.index, loser_weighted_return["Sum"])
plt.show()

# %%
winner_portfolio.to_csv("01_winner_portfolio.csv", index=False)
loser_portfolio.to_csv("01_loser_portfolio.csv", index=False)

# %%
winnerstocks = pd.DataFrame(columns=["Stocks","Weights",'last_price'])
for st in winner_cleaned_weights:
    winnerstocks.loc[len(winnerstocks.index)+1,"Stocks"]=st
    winnerstocks.loc[len(winnerstocks.index),"Weights"]=winner_cleaned_weights[st]
    winnerstocks.loc[len(winnerstocks.index),"last_price"]=weeklydfcopy.loc[weeklydfcopy.index[-1],st]
winnerstocks.sort_values(by="Weights", ascending=False, inplace=True)
winnerstocks

# %%
loserstocks = pd.DataFrame(columns=["Stocks","Weights",'last_price'])
for st in loser_cleaned_weights:
    loserstocks.loc[len(loserstocks.index)+1,"Stocks"]=st
    loserstocks.loc[len(loserstocks.index),"Weights"]=loser_cleaned_weights[st]
    loserstocks.loc[len(loserstocks.index),"last_price"]=weeklydfcopy.loc[weeklydfcopy.index[-1],st]
loserstocks.sort_values(by="Weights", ascending=False, inplace=True)
loserstocks
